# %% [markdown]
# # Topic 4 -- Neural Networks
#
# As we move on to using larger, more complex datasets, we soon run into an issue -- traditional linear and logistic regression is no longer sufficient to learn from those datasets. One might suggest to add a few extra features, like we did with polynomial regression, however when working with complex datasets already with many features, `PolynomialFeatures` would simply be too much and slow down computation dramatically.
#
# Neural networks are state-of-the-art ML architectures derived from the humble logistic regression, and due to its "deep" nature, it is able to solve some of the most complex ML problems, kicking off the era of **Deep Learning**. In this notebook, you are going to learn about the structure of a neural network, as well as various other activation functions which together allow a neural network to learn much more complicated hypothesis functions.

# %% [markdown]
# ## Table of Contents
#
# 1. [Installing Dependencies](#installing)
#
#
# 2. [Logistic Regression vs Neural Networks](#lvn)
#     - [Neuron Representation of Logistic Regression](#neuronrep)
#     - [Stacking Logistic Regression Units](#stacking)
#
#
# 3. [Neural Networks](#nn)
#     - [Layers](#termin)
#     - [Activation Function](#act)
#     - [Why do we need an Activation Function](#why)
#
#
# 4. [How Neural Networks Learn](#learn)
#     - [Forward Propagation](#forward)
#     - [Calculating Cost](#cost)
#     - [Back Propagation](#backprop)
#     - [Update all $w$ and $b$](#update)
#
#
# 5. [Neural Network Applications](#applications)
#     - [Multi-class Classification](#mclass)
#     - [Multi-task Classification](#mtask)
#
#
# 6. [Neural Networks In Action](#action)
#     - [Creating the Ultimate Candy](#candy)
#     - [Visualizing the Dataset](#dataset)
#     - [Training the Neural Network](#training)
#     - [How Accuracy is Calculated in SKLearn](#acc)
#     - [Other Metrics](#other)
#     - [Conclusions](#conclusions)

# %% [markdown]
# ## Installing Dependencies <a name="installing">
#
# Before we begin, we first need to install some modules we are going to use in this notebook. Here is a brief description of the modules:
#
# - **Numpy**: A powerful linear algebra library.
# - **Pandas**: Used to organize our dataset.
# - **SKLearn**: A highly abstract machine learning library.
# - **MatPlotLib**, **SeaBorn**, and **Bokeh**: Data visualization libraries for plotting our dataset.
# - **utils.py**: A custom module used to display graphics used in this notebook

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sn
from bokeh.plotting import figure, show, output_notebook
from utils import *

# %% [markdown]
# ## Logistic Regression vs Neural Networks <a name="lvn">
#
# You've all seen Logistic Regression -- It consists of performing a **linear sum** and then feeding the sum into a **sigmoid** function, which gives you the output (then there is the whole gradient calculation process that updates the parameters). Believe it or not, Neural Networks are very similar. In fact, **a Neural Network is a bunch of Logistic Regression units stacked on top of one another**. To understand how it works, we need to look at the **"Neuron Representation" of Logistic Regression**.

# %% [markdown]
# ### Neuron Representation of Logistic Regression <a name="neuronrep">
#
# In the image below, we represent Logistic Regression as a connection of "Neurons":
#
# <img src="images/logistic.png" alt="Cannot Display Image" width=900>
#
# Here you can see that each of the inputs $x_1, x_2, ..., x_5$ are represented by its own neuron, and the weight parameters $w_1, ..., w_5$ represents **how strong** the connection of each input is. All of the weighted inputs are summed up to form the weighted sum $z$, which is then fed through the sigmoid function to produce the output $\hat{y}$
#
#
# In Topic 2, we discussed about multiclass classification, where we are essentially training **multiple** Logistic Regression classifiers, each one to predict on a certain **class**. Here we show three classifiers used to predict on **orcas, ostriches, and deer**.
#
# <img src="images/logmulti.png" alt="Cannot Display Image" width=900>
#
# Notice that these three models can be simplified a little -- since they share the same input (you can feed the same image of an orca into all of these classifiers, and one of them will output a 1), you can merge the three models into **one model** with **three outputs**:
#
# <img src="images/logmultimerged.png" alt="Cannot Display Image" width=900>

# %% [markdown]
# ### Stacking Logistic Regression Units <a name="stacking">
#
# So far, we know that Logistic Regression is able to learn from the **input data** to make predictions. *What if we are able to train a Logistic Regression model that learns from the output of another Logistic Regression model?* In other words, *what if we use the output of one Logistic Regression model as the input of another one?*
#
# <img src="images/NN.png" alt="Cannot Display Image" width=900>
#
# This forms the concept of a **Neural Network**. Each layer in a Neural Network is a Logistic Regression Unit that is learning the output of the previous layer! Because you are chaining together multiple Logistic Regression units, a Neural Network is able to learn hypothesis functions that are far more complex than a single Logistic Regression unit can.
#
# ---

# %% [markdown]
# ## Neural Networks <a name="nn">
#
# ### Layers <a name="layers">
#
# Neural Networks can come in all shapes and sizes -- particularly, we can talk about the **number of layers** in a neural network, as well as the **number of neurons in each layer**. When we count the number of layers in a Neural Network, we count all BUT the input layer. For example, the picture you see above is a **two-layer neural network**. Just a side note, Logistic Regression models are also Neural Networks -- albeit with only one layer.
#
# A bit ago we mentioned about the "deep" nature of a Neural Network. The **depth** of a neural network refers to the number of layers in a network. We've found that deeper networks are able to solve more complicated problems such as Natural Language Processing and Computer Vision.
#
# There are three main types of layers in a Neural Network: the **input** layer, the **hidden** layers, and the **output** layer:
#
# <img src="images/layers.png" alt="Cannot Display Image" width=900>
#
# **Input Layer**: These neurons recieve the input data and feed it into the Neural Network. You've seen these quite a bit before.
#
# **Output Layer**: These neurons perform the final activation of the data before outputting it as the prediction. <u>**The output layer determines what problem your Neural Network is solving! If you do not use an activation function, and you use the MSE cost function, then your Neural Network will solve regression problems. If your output layer uses the sigmoid activation as well as BCE cost, then your Neural Network will solve classification problems**</u>
#
# **Hidden Layers**: These layers are called "Hidden" layers because what exactly happens here is unknown. In a Neural Network, what you can easily **visualize** are the contents of the **input layer** and the **output layer**, however the hidden layer is like a **"black box"** where the patterns each neuron learns cannot easily be predicted. In the programming exercise, we will print out the activations in the hidden layers.
#
# The term **"Forward Propagation"** is often use in the context of Neural Networks. This is to describe the input data propagating forward through each and every layer, until it arrives at the output as the prediction.
#
#
# #### In Summary:
#
# The input layer handels feeding in your data to the Neural Network.
#
# The output layer decides the type of problem your Neural Network is going to solve, whether it is regression or classification
#
# The hidden layers allows the Neural Network to solve more complicated problems, and **this is what differentiates Neural Networks from basic Linear or Logistic Regression**.

# %% [markdown]
# ### Activation Functions <a name="act">
#
# Back when we introduced Logistic Regression, we introduced the idea of the **sigmoid activation function** which bounds the output between 0 and 1. Turns out, while you can use the sigmoid function in a Neural Network, it is often not preferred in the hidden layers. This is because sigmoid functions have slopes that are very shallow, thus significantly slowing down learning.
#
# The **Tanh** activation function is often used instead of sigmoid, because its slopes are generally steeper, thus Neural Networks train faster using the Tanh function. Let's take a look at the Tanh function and compare it to the sigmoid function we programmed last time.

# %%
""" Supported functions:
Tanh
Sigmoid
Linear
ReLU
ELU
Leaky ReLU
"""

disp_2_func("Tanh", "Sigmoid")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2477">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c3fec507-fbfe-4a2c-882d-14d530b68a94" data-root-id="2391"></div>

# %% [markdown]
# Another popular activation function is the **ReLU** activation function, which stands for **Rectified Linear Unit**. This function is even faster than Tanh, and has recently gained traction as a favourite among deep learning researchers. The ReLU function is linear if $z = 0$, and is $0$ if $z < 0$

# %%
disp_2_func("ReLU", "Sigmoid")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2203">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e8e7aaf1-3b1e-42ec-9fe8-56a9d24385c8" data-root-id="2117"></div>

# %% [markdown]
# So far we have given reasons to NOT use the sigmoid function, however that does not mean it is completely useless. If you are developing a Neural Network for **classification problems**, you would want the **output layer** to use a **sigmoid activation**. In the same sense, if you are developing a Neural Network for **regression problems**, you would use a **linear** activation on the last layer. In other words, linear equals no activation.

# %% [markdown]
# ### Why do we need an Activation Function? <a name="why">
#
# So far we've introduced you to a plethora of activation functions, but the question remains, *\"Why do we need activation functions in the first place?\"* It seems like getting rid of activation functions will still allow data to be propagated from one layer to the next, so what gives?
#
# The formal answer requires a mathematical proof, and since this course does not go into the math behind Machine Learning, we are going to answer it without the proof (if you want the proof regardless, it is down below). **Using a Neural Network without any activation functions will effectively render all hidden layers useless. Your Neural Network will essentially behave like a single layer Neural Network (keep in mind that we don't count the input layer as a layer).**
#
# <img src="images/activation.png" alt="Cannot display image" width="900px">
#
# #### Proof for the Math Savvy
#
# Notice that all activation functions are **Non-Linear** (except for the Linear activation function, obviously). The reason why Neural Networks behave like a one layer network when you use Linear activations is because the calculations for weighted sum are linear. Here we start off by defining the weighted sum:
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $z^{[l]} = W^{[l]}a^{[l-1]} + b^{[l]}$
#
# </div>
#
# Where:
# - $z$ is the weighted sum of the layer $l$
# - $W$ is the weight matrix of the layer $l$
# - $a$ is the activation of the layer $l$
# - $b$ is the bias of the layer $l$
# - $l$ is the layer index
#
# Suppose our activation is linear, therefore:
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $a^{[l]} = z^{[l]}$
#
# </div>
#
# Now we define the weighted sum for the next layer:
#
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $z^{[l+1]} = W^{[l+1]}a^{[l]} + b^{[l+1]}$
#
# </div>
#
# And now, we sub in $a^{[l]}$ and simplify:
#
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $z^{[l+1]} = W^{[l+1]}(W^{[l]}a^{[l-1]} + b^{[l]}) + b^{[l+1]}$
# </div>
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $z^{[l+1]} = W'a^{[l-1]} + b'$
# </div>
#
# Where:
# - $W' = W^{[l+]}W^{[l]}$
# - $b' = W^{[l+1]}b^{[l]} + b^{[l+1]}$
#
# Here, we can see that **we condensed two layers into one!** In fact we can continue to combine layers, effectively **reducing a multi-layer Neural Network into a single layer Neural Network** (with the computational complexity of the multi-layer net).
#
# ---

# %% [markdown]
# ## How Neural Networks Learn <a name="learn">
#
# By now, you have learned how Linear Regression models and Logistic Regression models learn to fit the training data. Turns out, since Neural Networks are essentially a bunch of Logistic Regression models chained together, the training procedure is very, very similar. Down below, we've detailed the steps taken by a Neural Network to fit the training data.
#
# ### Forward Propagation <a name="forward">
#
# Forward propagation is the process of a Neural Network **making a prediction**. Each layer of the network has its own collection of weights $w$ and bias $b$. Information from one layer is **propagated** forward into the next layer, until it reaches the output layer.
#
# <img src="images/fp.png" alt="Cannot display image" width=700>
#
# ### Calculating Cost <a name="cost">
#
# Forward propagation takes an input and outputs a **prediction**. The next step is to see how **\"wrong\"** our prediction is. Here we calculate the cost of our prediction given the current state of all $w$ and $b$. This would measure how far off we are from the actual labels. Remember, if we developed a neural network for regression purposes, we would use a **linear activation** in the last layer and **MSE cost**. If we develop a Neural Network for classification purposes, then we would use **sigmoid** or **softmax** activation for the last layer and **BCE** or **CCE** cost (**SPOILER ALERT!!!** softmax and CCE loss will be covered soon!)
#
# ### Back Propagation <a name="backward">
#
# The Back Propagation process, we take the cost evaluated by the cost function and calculate the slopes (gradients) of the cost with respect with the weights and biases of the last layer. Then the **errors are propagated backwards through each layer** until we have the slopes of the cost with respect to every $w$ and $b$.
#
# <img src="images/bp.png" alt="Cannot display image" width=700>
#
# ### Update all $w$ and $b$ <a name="update">
#
# The final step is to update all the $w$ and $b$ with its respective **gradients**. These four steps are carried out iteratively until all the $w$ and $b$ are at their optimal values to make predictions with the lowest cost. Overall, these steps are very similar to the learning procedure of Linear Regression and Logistic Regression.
#
# ---

# %% [markdown]
# ## Neural Network Applications <a name="applications">
#
# So far, we have tackled regression and classification problems using Linear and Logistic Regression. Neural Networks take that one step further, being able to tackle these problems with incredible accuracy and performance. While we won't talk about regression and binary classification problems, as we have done this before and the process is very similar on Neural Networks, we are going to revisit **multi-class** classification, as well as introduce a new type of classification called **multi-task classification**
#
#
# ### Multi-class Classification <a name="mclass">
#
# The general gist of multi-class classification remains the same -- we are predicting on $n$ classes with $n$ output neurons in the output layer. Remember, this is very similar to training multiple Neural Networks for each class! The output neurons each have **sigmoid** activations, and the cost function used to evaluate the prediction error is **Binary Cross Entropy**. An example prediction from the multi-class neural network is shown below:
#
# <img src="images/sigmoid-multiclass.png" alt="Cannot display image" width=900>
#
# #### Softmax Activation
#
# As previously alluded, we are going to talk about another activation function. When performing multi-class classification, while the sigmoid activation function works very well, often times deep learning practitioners prefer the softmax activation function. Here's the formula for the function, even though we don't require you to know it for the course:
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $\begin{align}\text{softmax}(z) = {e^z \over \sum\limits_{j=1}^{n^{[L]}}e^z_j}\end{align}$
#
# </div>
#
# Down below is shows the same Neural Network equipped with the softmax function on the output layer:
#
# <img src="images/softmax-multiclass.png" alt="Cannot display image" width=900>
#
# See any differences? **The softmax activation function makes sure the output probabilities sum to 1**. This is the main reason why experts prefer softmax over sigmoid for multi-class classification, as it doesn't really make sense for an image to have a 70% probability to be an orca, and 40% probability to be a deer.
#
# #### Categorical Cross Entropy
#
# Since we are using a new activation function, we also need to use a different **cost** function. Neural Networks using the **softmax** activation function should use the **Categorical Cross Entropy (CCE)** cost function. This is slightly simpler than **BCE**, and thus slightly quicker.
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     $\begin{align}\text{CCE}(w, b) = {1\over m}\sum\limits_{i=1}^m \sum\limits_{j=1}^C y_j^{(i)}\log(\hat{y_j}^{(i)})\end{align}$
#
# </div>
#
#
# **In summary**, from now on when we build a multi-class classifer, we are going to use **softmax activation** and **CCE** instead of **sigmoid activation** and **BCE**

# %% [markdown]
# ### Multi-task Classification <a name="mtask">
#
# Multi-task classification works similarly to multi-class classification, however the key difference is multi-task classification allows for **multiple** output neurons to output 1, whereas in multi-class classification only one output neuron can output 1 at any time, which denotes the **class** of the input data
#
# One example of Multi-task classification is in **self driving cars**. When the camera system in a self driving car captures the scene, the picture is not limited to only have traffic lights, or only to have pedestrians, or only to have street signs. The image might have pedestrians **and** street signs, or any combination of those three. For example, if we denote the label $y_1$ to be **pedestrians**, $y_2$ to be **stop signs**, and $y_3$ to be **traffic lights**, following label would represent an image with **pedestrians** and **traffic lights**:
#
# <div style="text-align: center">
#     <div>
#         &nbsp;
#     </div>
#     <img src="images/traffic.jpg" alt="cannot load image" width=400>
#     <div>
#         &nbsp;
#     </div>
#     $\hat{y} \  =  \ \begin{bmatrix}1 \\ 0 \\ 1\end{bmatrix} \begin{matrix}\implies\text{pedestrians} \\ \implies\text{no stop signs} \\  \implies\text{traffic lights}\end{matrix}$
#
# </div>
#
# Here, since the output doesn't have to sum to 1, we will use the **sigmoid activation** function along with **BCE loss**.
#
# ---

# %% [markdown]
# ## Neural Networks In Action <a name="action"></a>
#
# Congrats on making it this far! Now that you have learned how a Neural Network works, as well as some new and refreshed applications of Neural Networks, its time to train one to see it in action! For the sake of simplicity, we are going to train the Neural Network using **SKLearn's** `MLPClassifier` class.
#
# > Note: "MLP" stands for "Multi Layer Perceptron". Perceptron is a fancy word for "Neuron", thus MLP basically means Neural Network!

# %% [markdown]
# ### Creating the Ultimate Candy <a name="candy"></a>
#
# Suppose you are running a **candy company** called **Skootles**. As with all candy companies, they want to maximize sales by creating a hit product that's going to fly off the store shelves. The product has to be **affordable** and **popular**. You notice that your competitors **N&N** has hired a handful of industry experts to analyze a dataset containing the **ingredients** of various candies and their corresponding **relative price** and **popularity**. You believe you can train a **Neural Network** that is going to cost much less than hiring experts, and possibly perform better as well.

# %% [markdown]
# ### Visualizing the Dataset <a name="dataset"></a>
#
# The first step is to understand what our data looks like. We will use the **The Ultimate Halloween Candy Power Ranking** dataset by [FiveThirtyEight](https://www.kaggle.com/fivethirtyeight/the-ultimate-halloween-candy-power-ranking/). Loading the dataset should be quite familiar to you, as this was done in many of our previous topics.

# %%
dataset = pd.read_csv("datasets/candy-data.csv")
dataset
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0        0                 1     0    1         0         0.732         0.860
# 1        1                 0     0    1         0         0.604         0.511
# 2        0                 0     0    0         0         0.011         0.116
# 3        0                 0     0    0         0         0.011         0.511
# 4        0                 0     0    0         0         0.906         0.511
# ..     ...               ...   ...  ...       ...           ...           ...
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# ..         ...
# 80   45.466282
# 81   39.011898
# 82   44.375519
# 83   41.904308
# 84   49.524113
#
# [85 rows x 13 columns]

# %% [markdown]
# Looking at the DataFrame we created, we can see a bunch of candy features ranging from `chocolate` to `pluribus`, as well as the `sugarpercent`, `pricepercent`, and `winpercent`. Our goal for this problem is to predict the **ingredients** that will go into our candy given the inputs for relative cost (`pricepercent`) as well as popularity (`winpercent`).
#
# Looking at the **first datapoint**, we can see that the candy in question contains **chocolate, caramel, rice wafer**, and is shaped like a **bar**. We want to be able to input the **price percentage** and **popularity**, and have the Neural Network output the optimal ingredients. That way, the candy makers at **Skootles** can input a high popularity, low price, and have the Neural Network predict on the ingredients needed to achieve that.
#
# <img src="images/candy.png" alt="cannot display images" width=900>
#
# #### Question for Students:
#
# What kind of problem is this? Is this Regression, Binary Classification, Multi-class Classification, or Multi-task Classification?

# %%
# Convert selected columns to Numpy
features = dataset[['pricepercent', 'winpercent']].to_numpy()
labels = dataset.iloc[:, 1:10].to_numpy()


print(f"Features shape: {features.shape}")
print(f"Labels shape: {labels.shape}")
# Out:
# Features shape: (85, 2)
# Labels shape: (85, 9)

# %% [markdown]
# ### Training the Neural Network <a name="training"></a>
#
#
# The next step is to preprocess the data. Everything is quite familiar here, except for the `StandardScaler` class. Recall in the previous topic, we learned that when features are on **vastly different scales**, the result is a **highly elliptical cost function** that is **tricky to traverse**. Implementing **standard normalization** in `LinearRegression` and `LogisticRegressionCV` was as simple as setting the `normalize` parameter to `True`. `MLPClassifier` however does not have that feature, so we have to implement it ourselves. The `StandardScaler` class is used to perform standard normalization to our data.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# Create polynomial features out of input
poly = PolynomialFeatures(degree=3)
# Used to normalize the input
scaler = StandardScaler()

X_train, X_test, Y_train, Y_test = train_test_split(features, labels, test_size=0.25)

# Poly transforms and Scaling
X_train = poly.fit_transform(X_train)
X_test = poly.fit_transform(X_test)

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# Now its time to implement our Neural Network in SKLearn. For this exercise, we are going to use **5 hidden layers** each with **3 neurons** to increase the complexity of hypothesis functions we could learn. `MLPClassifier` has already pre-set the output layer's activation function to **sigmoid**, which is great because this is a multi-task classification problem
#
# What we need to specify is the activation function for the hidden units.
#
# #### Question for the students
#
# `MLPClassifier` allows us to specify the activation function for the hidden units to be `"linear"`. Should we? Should we not? Why?

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(hidden_layer_sizes=(3, 3, 3, 3, 3), activation="relu", verbose=True, max_iter=10000, alpha=1e-4)

model.fit(X_train, Y_train)
# Out:
# Iteration 1, loss = 6.37821490
# Iteration 2, loss = 6.37233774
# Iteration 3, loss = 6.36638186
# Iteration 4, loss = 6.36035277
# Iteration 5, loss = 6.35436585
# Iteration 6, loss = 6.34837503
# Iteration 7, loss = 6.34237182
# Iteration 8, loss = 6.33623156
# Iteration 9, loss = 6.32994428
# Iteration 10, loss = 6.32366177
# Iteration 11, loss = 6.31738416
# Iteration 12, loss = 6.31109712
# Iteration 13, loss = 6.30480143
# Iteration 14, loss = 6.29849788
# Iteration 15, loss = 6.29217828
# Iteration 16, loss = 6.28585077
# Iteration 17, loss = 6.27968392
# Iteration 18, loss = 6.27358337
# Iteration 19, loss = 6.26747613
# Iteration 20, loss = 6.26131514
# Iteration 21, loss = 6.25512881
# Iteration 22, loss = 6.24892870
# Iteration 23, loss = 6.24272576
# Iteration 24, loss = 6.23652483
# Iteration 25, loss = 6.23031671
# Iteration 26, loss = 6.22413256
# Iteration 27, loss = 6.21800097
# Iteration 28, loss = 6.21185677
# Iteration 29, loss = 6.20567484
# Iteration 30, loss = 6.19944291
# Iteration 31, loss = 6.19319856
# Iteration 32, loss = 6.18694526
# Iteration 33, loss = 6.18068091
# Iteration 34, loss = 6.17439934
# Iteration 35, loss = 6.16824544
# Iteration 36, loss = 6.16210436
# Iteration 37, loss = 6.15596363
# Iteration 38, loss = 6.14994146
# Iteration 39, loss = 6.14401618
# Iteration 40, loss = 6.13809304
# Iteration 41, loss = 6.13217464
# Iteration 42, loss = 6.12625971
# Iteration 43, loss = 6.12033426
# Iteration 44, loss = 6.11447697
# Iteration 45, loss = 6.10871758
# Iteration 46, loss = 6.10298168
# Iteration 47, loss = 6.09734368
# Iteration 48, loss = 6.09203804
# Iteration 49, loss = 6.08674283
# Iteration 50, loss = 6.08145066
# Iteration 51, loss = 6.07616146
# Iteration 52, loss = 6.07087562
# Iteration 53, loss = 6.06559080
# Iteration 54, loss = 6.06030668
# Iteration 55, loss = 6.05502296
# Iteration 56, loss = 6.04973939
# Iteration 57, loss = 6.04445573
# Iteration 58, loss = 6.03917180
# Iteration 59, loss = 6.03388814
# Iteration 60, loss = 6.02863986
# Iteration 61, loss = 6.02339086
# Iteration 62, loss = 6.01814113
# Iteration 63, loss = 6.01289065
# Iteration 64, loss = 6.00763942
# Iteration 65, loss = 6.00238757
# Iteration 66, loss = 5.99712431
# Iteration 67, loss = 5.99185851
# Iteration 68, loss = 5.98659056
# Iteration 69, loss = 5.98132071
# Iteration 70, loss = 5.97604921
# Iteration 71, loss = 5.97077626
# Iteration 72, loss = 5.96554078
# Iteration 73, loss = 5.96029547
# Iteration 74, loss = 5.95504912
# Iteration 75, loss = 5.94980195
# Iteration 76, loss = 5.94455417
# Iteration 77, loss = 5.93930597
# Iteration 78, loss = 5.93405749
# Iteration 79, loss = 5.92880888
# Iteration 80, loss = 5.92356016
# Iteration 81, loss = 5.91831070
# Iteration 82, loss = 5.91305321
# Iteration 83, loss = 5.90779390
# Iteration 84, loss = 5.90253421
# Iteration 85, loss = 5.89727431
# Iteration 86, loss = 5.89201346
# Iteration 87, loss = 5.88673334
# Iteration 88, loss = 5.88145151
# Iteration 89, loss = 5.87616822
# Iteration 90, loss = 5.87088377
# Iteration 91, loss = 5.86559842
# Iteration 92, loss = 5.86031245
# Iteration 93, loss = 5.85502042
# Iteration 94, loss = 5.84948066
# Iteration 95, loss = 5.84358130
# Iteration 96, loss = 5.83754729
# Iteration 97, loss = 5.83137384
# Iteration 98, loss = 5.82510907
# Iteration 99, loss = 5.81877003
# Iteration 100, loss = 5.81236941
# Iteration 101, loss = 5.80591724
# Iteration 102, loss = 5.79942151
# Iteration 103, loss = 5.79288865
# Iteration 104, loss = 5.78632350
# Iteration 105, loss = 5.77972999
# Iteration 106, loss = 5.77311195
# Iteration 107, loss = 5.76647211
# Iteration 108, loss = 5.75981277
# Iteration 109, loss = 5.75316279
# Iteration 110, loss = 5.74662311
# Iteration 111, loss = 5.74007709
# Iteration 112, loss = 5.73352492
# Iteration 113, loss = 5.72697880
# Iteration 114, loss = 5.72047852
# Iteration 115, loss = 5.71397442
# Iteration 116, loss = 5.70746623
# Iteration 117, loss = 5.70095462
# Iteration 118, loss = 5.69443818
# Iteration 119, loss = 5.68791657
# Iteration 120, loss = 5.68138948
# Iteration 121, loss = 5.67485660
# Iteration 122, loss = 5.66831766
# Iteration 123, loss = 5.66177237
# Iteration 124, loss = 5.65522262
# Iteration 125, loss = 5.64867643
# Iteration 126, loss = 5.64215076
# Iteration 127, loss = 5.63561811
# Iteration 128, loss = 5.62907972
# Iteration 129, loss = 5.62253538
# Iteration 130, loss = 5.61598517
# Iteration 131, loss = 5.60942955
# Iteration 132, loss = 5.60286734
# Iteration 133, loss = 5.59629837
# Iteration 134, loss = 5.58972266
# Iteration 135, loss = 5.58314064
# Iteration 136, loss = 5.57655257
# Iteration 137, loss = 5.56995763
# Iteration 138, loss = 5.56335565
# Iteration 139, loss = 5.55674673
# Iteration 140, loss = 5.55013099
# Iteration 141, loss = 5.54350847
# Iteration 142, loss = 5.53694769
# Iteration 143, loss = 5.53041182
# Iteration 144, loss = 5.52386890
# Iteration 145, loss = 5.51732233
# Iteration 146, loss = 5.51077848
# Iteration 147, loss = 5.50426846
# Iteration 148, loss = 5.49777240
# Iteration 149, loss = 5.49127592
# Iteration 150, loss = 5.48479153
# Iteration 151, loss = 5.47833940
# Iteration 152, loss = 5.47188191
# Iteration 153, loss = 5.46545788
# Iteration 154, loss = 5.46008475
# Iteration 155, loss = 5.45502204
# Iteration 156, loss = 5.44996370
# Iteration 157, loss = 5.44491106
# Iteration 158, loss = 5.43986536
# Iteration 159, loss = 5.43482768
# Iteration 160, loss = 5.42979901
# Iteration 161, loss = 5.42478021
# Iteration 162, loss = 5.41977206
# Iteration 163, loss = 5.41477525
# Iteration 164, loss = 5.40979040
# Iteration 165, loss = 5.40481806
# Iteration 166, loss = 5.39985870
# Iteration 167, loss = 5.39491278
# Iteration 168, loss = 5.38998066
# Iteration 169, loss = 5.38506269
# Iteration 170, loss = 5.38015918
# Iteration 171, loss = 5.37527036
# Iteration 172, loss = 5.37039647
# Iteration 173, loss = 5.36553775
# Iteration 174, loss = 5.36069440
# Iteration 175, loss = 5.35586661
# Iteration 176, loss = 5.35105453
# Iteration 177, loss = 5.34625832
# Iteration 178, loss = 5.34147810
# Iteration 179, loss = 5.33671402
# Iteration 180, loss = 5.33196620
# Iteration 181, loss = 5.32723474
# Iteration 182, loss = 5.32251975
# Iteration 183, loss = 5.31782107
# Iteration 184, loss = 5.31313899
# Iteration 185, loss = 5.30847362
# Iteration 186, loss = 5.30382507
# Iteration 187, loss = 5.29919343
# Iteration 188, loss = 5.29457881
# Iteration 189, loss = 5.28998133
# Iteration 190, loss = 5.28540109
# Iteration 191, loss = 5.28083820
# Iteration 192, loss = 5.27629278
# Iteration 193, loss = 5.27176494
# Iteration 194, loss = 5.26725488
# Iteration 195, loss = 5.26276267
# Iteration 196, loss = 5.25828842
# Iteration 197, loss = 5.25383228
# Iteration 198, loss = 5.24939434
# Iteration 199, loss = 5.24497459
# Iteration 200, loss = 5.24057334
# Iteration 201, loss = 5.23619073
# Iteration 202, loss = 5.23182693
# Iteration 203, loss = 5.22748202
# Iteration 204, loss = 5.22315622
# Iteration 205, loss = 5.21884968
# Iteration 206, loss = 5.21456258
# Iteration 207, loss = 5.21029508
# Iteration 208, loss = 5.20604745
# Iteration 209, loss = 5.20182030
# Iteration 210, loss = 5.19761329
# Iteration 211, loss = 5.19342660
# Iteration 212, loss = 5.18926040
# Iteration 213, loss = 5.18511436
# Iteration 214, loss = 5.18098869
# Iteration 215, loss = 5.17688389
# Iteration 216, loss = 5.17280018
# Iteration 217, loss = 5.16873772
# Iteration 218, loss = 5.16469672
# Iteration 219, loss = 5.16067735
# Iteration 220, loss = 5.15668006
# Iteration 221, loss = 5.15270491
# Iteration 222, loss = 5.14875195
# Iteration 223, loss = 5.14482315
# Iteration 224, loss = 5.14092670
# Iteration 225, loss = 5.13705373
# Iteration 226, loss = 5.13320431
# Iteration 227, loss = 5.12937849
# Iteration 228, loss = 5.12557635
# Iteration 229, loss = 5.12179795
# Iteration 230, loss = 5.11804335
# Iteration 231, loss = 5.11431262
# Iteration 232, loss = 5.11060579
# Iteration 233, loss = 5.10692306
# Iteration 234, loss = 5.10326462
# Iteration 235, loss = 5.09963024
# Iteration 236, loss = 5.09601994
# Iteration 237, loss = 5.09243373
# Iteration 238, loss = 5.08887163
# Iteration 239, loss = 5.08533376
# Iteration 240, loss = 5.08182001
# Iteration 241, loss = 5.07833031
# Iteration 242, loss = 5.07486461
# Iteration 243, loss = 5.07142285
# Iteration 244, loss = 5.06800495
# Iteration 245, loss = 5.06461083
# Iteration 246, loss = 5.06124038
# Iteration 247, loss = 5.05789348
# Iteration 248, loss = 5.05457003
# Iteration 249, loss = 5.05127041
# Iteration 250, loss = 5.04799396
# Iteration 251, loss = 5.04474051
# Iteration 252, loss = 5.04150987
# Iteration 253, loss = 5.03830183
# Iteration 254, loss = 5.03511594
# Iteration 255, loss = 5.03195119
# Iteration 256, loss = 5.02880814
# Iteration 257, loss = 5.02568653
# Iteration 258, loss = 5.02258608
# Iteration 259, loss = 5.01950653
# Iteration 260, loss = 5.01644738
# Iteration 261, loss = 5.01340956
# Iteration 262, loss = 5.01039129
# Iteration 263, loss = 5.00739265
# Iteration 264, loss = 5.00441328
# Iteration 265, loss = 5.00145280
# Iteration 266, loss = 4.99851086
# Iteration 267, loss = 4.99558716
# Iteration 268, loss = 4.99269182
# Iteration 269, loss = 4.98981202
# Iteration 270, loss = 4.98694745
# Iteration 271, loss = 4.98409785
# Iteration 272, loss = 4.98126324
# Iteration 273, loss = 4.97844307
# Iteration 274, loss = 4.97564266
# Iteration 275, loss = 4.97286349
# Iteration 276, loss = 4.97010216
# Iteration 277, loss = 4.96734844
# Iteration 278, loss = 4.96460635
# Iteration 279, loss = 4.96187620
# Iteration 280, loss = 4.95915739
# Iteration 281, loss = 4.95644953
# Iteration 282, loss = 4.95375221
# Iteration 283, loss = 4.95106497
# Iteration 284, loss = 4.94838736
# Iteration 285, loss = 4.94571888
# Iteration 286, loss = 4.94305905
# Iteration 287, loss = 4.94040742
# Iteration 288, loss = 4.93776316
# Iteration 289, loss = 4.93512287
# Iteration 290, loss = 4.93248844
# Iteration 291, loss = 4.92985481
# Iteration 292, loss = 4.92722433
# Iteration 293, loss = 4.92460285
# Iteration 294, loss = 4.92198366
# Iteration 295, loss = 4.91936622
# Iteration 296, loss = 4.91675027
# Iteration 297, loss = 4.91414343
# Iteration 298, loss = 4.91153539
# Iteration 299, loss = 4.90892449
# Iteration 300, loss = 4.90632047
# Iteration 301, loss = 4.90371578
# Iteration 302, loss = 4.90110894
# Iteration 303, loss = 4.89849953
# Iteration 304, loss = 4.89588710
# Iteration 305, loss = 4.89327758
# Iteration 306, loss = 4.89066968
# Iteration 307, loss = 4.88801779
# Iteration 308, loss = 4.88535922
# Iteration 309, loss = 4.88269287
# Iteration 310, loss = 4.88001488
# Iteration 311, loss = 4.87732712
# Iteration 312, loss = 4.87463633
# Iteration 313, loss = 4.87195189
# Iteration 314, loss = 4.86925987
# Iteration 315, loss = 4.86656456
# Iteration 316, loss = 4.86385702
# Iteration 317, loss = 4.86113650
# Iteration 318, loss = 4.85841367
# Iteration 319, loss = 4.85567974
# Iteration 320, loss = 4.85292924
# Iteration 321, loss = 4.85017036
# Iteration 322, loss = 4.84740308
# Iteration 323, loss = 4.84462030
# Iteration 324, loss = 4.84182413
# Iteration 325, loss = 4.83901476
# Iteration 326, loss = 4.83620258
# Iteration 327, loss = 4.83337502
# Iteration 328, loss = 4.83052728
# Iteration 329, loss = 4.82768237
# Iteration 330, loss = 4.82480170
# Iteration 331, loss = 4.82190266
# Iteration 332, loss = 4.81890179
# Iteration 333, loss = 4.81573160
# Iteration 334, loss = 4.81275130
# Iteration 335, loss = 4.80966620
# Iteration 336, loss = 4.80641432
# Iteration 337, loss = 4.80314007
# Iteration 338, loss = 4.79990899
# Iteration 339, loss = 4.79710834
# Iteration 340, loss = 4.79427275
# Iteration 341, loss = 4.79154634
# Iteration 342, loss = 4.78855144
# Iteration 343, loss = 4.78546492
# Iteration 344, loss = 4.78214211
# Iteration 345, loss = 4.77868039
# Iteration 346, loss = 4.77549497
# Iteration 347, loss = 4.77192845
# Iteration 348, loss = 4.76842989
# Iteration 349, loss = 4.76536825
# Iteration 350, loss = 4.76240857
# Iteration 351, loss = 4.75959844
# Iteration 352, loss = 4.75683440
# Iteration 353, loss = 4.75403398
# Iteration 354, loss = 4.75123457
# Iteration 355, loss = 4.74842006
# Iteration 356, loss = 4.74557151
# Iteration 357, loss = 4.74273127
# Iteration 358, loss = 4.73989509
# Iteration 359, loss = 4.73706543
# Iteration 360, loss = 4.73424454
# Iteration 361, loss = 4.73143303
# Iteration 362, loss = 4.72865062
# Iteration 363, loss = 4.72587438
# Iteration 364, loss = 4.72302138
# Iteration 365, loss = 4.72015300
# Iteration 366, loss = 4.71728711
# Iteration 367, loss = 4.71464260
# Iteration 368, loss = 4.71209327
# Iteration 369, loss = 4.70954374
# Iteration 370, loss = 4.70699362
# Iteration 371, loss = 4.70442905
# Iteration 372, loss = 4.70185867
# Iteration 373, loss = 4.69929048
# Iteration 374, loss = 4.69672442
# Iteration 375, loss = 4.69415520
# Iteration 376, loss = 4.69158234
# Iteration 377, loss = 4.68907405
# Iteration 378, loss = 4.68660695
# Iteration 379, loss = 4.68414529
# Iteration 380, loss = 4.68168949
# Iteration 381, loss = 4.67924107
# Iteration 382, loss = 4.67679940
# Iteration 383, loss = 4.67436431
# Iteration 384, loss = 4.67193204
# Iteration 385, loss = 4.66950819
# Iteration 386, loss = 4.66709647
# Iteration 387, loss = 4.66469723
# Iteration 388, loss = 4.66231240
# Iteration 389, loss = 4.65993908
# Iteration 390, loss = 4.65757408
# Iteration 391, loss = 4.65521720
# Iteration 392, loss = 4.65286824
# Iteration 393, loss = 4.65050126
# Iteration 394, loss = 4.64810712
# Iteration 395, loss = 4.64564364
# Iteration 396, loss = 4.64314863
# Iteration 397, loss = 4.64061240
# Iteration 398, loss = 4.63802801
# Iteration 399, loss = 4.63555002
# Iteration 400, loss = 4.63317546
# Iteration 401, loss = 4.63084727
# Iteration 402, loss = 4.62852497
# Iteration 403, loss = 4.62636539
# Iteration 404, loss = 4.62416504
# Iteration 405, loss = 4.62189567
# Iteration 406, loss = 4.61955237
# Iteration 407, loss = 4.61729682
# Iteration 408, loss = 4.61510636
# Iteration 409, loss = 4.61292350
# Iteration 410, loss = 4.61074066
# Iteration 411, loss = 4.60855756
# Iteration 412, loss = 4.60636365
# Iteration 413, loss = 4.60420820
# Iteration 414, loss = 4.60205624
# Iteration 415, loss = 4.59990387
# Iteration 416, loss = 4.59775229
# Iteration 417, loss = 4.59566000
# Iteration 418, loss = 4.59356925
# Iteration 419, loss = 4.59148020
# Iteration 420, loss = 4.58939304
# Iteration 421, loss = 4.58730793
# Iteration 422, loss = 4.58522504
# Iteration 423, loss = 4.58314449
# Iteration 424, loss = 4.58115058
# Iteration 425, loss = 4.57909877
# Iteration 426, loss = 4.57698212
# Iteration 427, loss = 4.57495294
# Iteration 428, loss = 4.57295386
# Iteration 429, loss = 4.57094460
# Iteration 430, loss = 4.56888915
# Iteration 431, loss = 4.56681592
# Iteration 432, loss = 4.56480884
# Iteration 433, loss = 4.56274932
# Iteration 434, loss = 4.56065159
# Iteration 435, loss = 4.55861217
# Iteration 436, loss = 4.55655659
# Iteration 437, loss = 4.55448602
# Iteration 438, loss = 4.55242501
# Iteration 439, loss = 4.55035283
# Iteration 440, loss = 4.54827729
# Iteration 441, loss = 4.54621108
# Iteration 442, loss = 4.54412893
# Iteration 443, loss = 4.54202527
# Iteration 444, loss = 4.53991645
# Iteration 445, loss = 4.53792358
# Iteration 446, loss = 4.53585548
# Iteration 447, loss = 4.53382468
# Iteration 448, loss = 4.53178729
# Iteration 449, loss = 4.52977743
# Iteration 450, loss = 4.52776331
# Iteration 451, loss = 4.52572630
# Iteration 452, loss = 4.52366805
# Iteration 453, loss = 4.52162392
# Iteration 454, loss = 4.51957340
# Iteration 455, loss = 4.51756480
# Iteration 456, loss = 4.51554650
# Iteration 457, loss = 4.51350363
# Iteration 458, loss = 4.51144918
# Iteration 459, loss = 4.50938903
# Iteration 460, loss = 4.50744395
# Iteration 461, loss = 4.50538166
# Iteration 462, loss = 4.50325934
# Iteration 463, loss = 4.50119100
# Iteration 464, loss = 4.49908806
# Iteration 465, loss = 4.49695373
# Iteration 466, loss = 4.49479153
# Iteration 467, loss = 4.49260513
# Iteration 468, loss = 4.49057024
# Iteration 469, loss = 4.48842488
# Iteration 470, loss = 4.48617772
# Iteration 471, loss = 4.48412800
# Iteration 472, loss = 4.48211383
# Iteration 473, loss = 4.48009356
# Iteration 474, loss = 4.47808628
# Iteration 475, loss = 4.47604847
# Iteration 476, loss = 4.47400382
# Iteration 477, loss = 4.47199659
# Iteration 478, loss = 4.46997519
# Iteration 479, loss = 4.46791468
# Iteration 480, loss = 4.46594649
# Iteration 481, loss = 4.46396190
# Iteration 482, loss = 4.46191685
# Iteration 483, loss = 4.45985416
# Iteration 484, loss = 4.45784477
# Iteration 485, loss = 4.45578625
# Iteration 486, loss = 4.45378050
# Iteration 487, loss = 4.45176165
# Iteration 488, loss = 4.44967236
# Iteration 489, loss = 4.44774539
# Iteration 490, loss = 4.44576786
# Iteration 491, loss = 4.44374424
# Iteration 492, loss = 4.44167264
# Iteration 493, loss = 4.43956250
# Iteration 494, loss = 4.43769913
# Iteration 495, loss = 4.43575770
# Iteration 496, loss = 4.43373729
# Iteration 497, loss = 4.43164091
# Iteration 498, loss = 4.42953871
# Iteration 499, loss = 4.42758523
# Iteration 500, loss = 4.42555688
# Iteration 501, loss = 4.42347240
# Iteration 502, loss = 4.42137995
# Iteration 503, loss = 4.41947740
# Iteration 504, loss = 4.41744250
# Iteration 505, loss = 4.41528431
# Iteration 506, loss = 4.41320877
# Iteration 507, loss = 4.41122138
# Iteration 508, loss = 4.40917640
# Iteration 509, loss = 4.40708483
# Iteration 510, loss = 4.40493564
# Iteration 511, loss = 4.40295253
# Iteration 512, loss = 4.40090177
# Iteration 513, loss = 4.39877111
# Iteration 514, loss = 4.39658299
# Iteration 515, loss = 4.39447150
# Iteration 516, loss = 4.39246235
# Iteration 517, loss = 4.39041090
# Iteration 518, loss = 4.38832300
# Iteration 519, loss = 4.38628341
# Iteration 520, loss = 4.38434475
# Iteration 521, loss = 4.38211608
# Iteration 522, loss = 4.37997797
# Iteration 523, loss = 4.37783028
# Iteration 524, loss = 4.37564785
# Iteration 525, loss = 4.37343680
# Iteration 526, loss = 4.37125869
# Iteration 527, loss = 4.36912906
# Iteration 528, loss = 4.36693113
# Iteration 529, loss = 4.36482084
# Iteration 530, loss = 4.36277153
# Iteration 531, loss = 4.36067525
# Iteration 532, loss = 4.35863308
# Iteration 533, loss = 4.35658370
# Iteration 534, loss = 4.35447898
# Iteration 535, loss = 4.35242147
# Iteration 536, loss = 4.35117037
# Iteration 537, loss = 4.34946676
# Iteration 538, loss = 4.34764775
# Iteration 539, loss = 4.34567862
# Iteration 540, loss = 4.34353726
# Iteration 541, loss = 4.34133110
# Iteration 542, loss = 4.33949481
# Iteration 543, loss = 4.33770144
# Iteration 544, loss = 4.33592079
# Iteration 545, loss = 4.33415865
# Iteration 546, loss = 4.33234454
# Iteration 547, loss = 4.33061863
# Iteration 548, loss = 4.32881447
# Iteration 549, loss = 4.32694188
# Iteration 550, loss = 4.32512404
# Iteration 551, loss = 4.32332254
# Iteration 552, loss = 4.32142801
# Iteration 553, loss = 4.31958942
# Iteration 554, loss = 4.31777759
# Iteration 555, loss = 4.31587969
# Iteration 556, loss = 4.31404028
# Iteration 557, loss = 4.31221099
# Iteration 558, loss = 4.31040748
# Iteration 559, loss = 4.30871899
# Iteration 560, loss = 4.30694649
# Iteration 561, loss = 4.30510458
# Iteration 562, loss = 4.30327763
# Iteration 563, loss = 4.30161561
# Iteration 564, loss = 4.29988558
# Iteration 565, loss = 4.29816281
# Iteration 566, loss = 4.29645239
# Iteration 567, loss = 4.29467325
# Iteration 568, loss = 4.29294563
# Iteration 569, loss = 4.29125844
# Iteration 570, loss = 4.28956374
# Iteration 571, loss = 4.28793240
# Iteration 572, loss = 4.28627568
# Iteration 573, loss = 4.28476610
# Iteration 574, loss = 4.28314486
# Iteration 575, loss = 4.28149933
# Iteration 576, loss = 4.27986558
# Iteration 577, loss = 4.27825532
# Iteration 578, loss = 4.27658602
# Iteration 579, loss = 4.27515287
# Iteration 580, loss = 4.27357861
# Iteration 581, loss = 4.27186933
# Iteration 582, loss = 4.27025930
# Iteration 583, loss = 4.26873759
# Iteration 584, loss = 4.26712900
# Iteration 585, loss = 4.26548539
# Iteration 586, loss = 4.26413679
# Iteration 587, loss = 4.26277848
# Iteration 588, loss = 4.26131869
# Iteration 589, loss = 4.25991983
# Iteration 590, loss = 4.25858825
# Iteration 591, loss = 4.25722504
# Iteration 592, loss = 4.25583255
# Iteration 593, loss = 4.25443042
# Iteration 594, loss = 4.25308435
# Iteration 595, loss = 4.25168362
# Iteration 596, loss = 4.25026579
# Iteration 597, loss = 4.24892798
# Iteration 598, loss = 4.24758540
# Iteration 599, loss = 4.24623838
# Iteration 600, loss = 4.24489545
# Iteration 601, loss = 4.24358918
# Iteration 602, loss = 4.24223249
# Iteration 603, loss = 4.24088991
# Iteration 604, loss = 4.23959169
# Iteration 605, loss = 4.23826741
# Iteration 606, loss = 4.23692449
# Iteration 607, loss = 4.23561108
# Iteration 608, loss = 4.23429397
# Iteration 609, loss = 4.23301113
# Iteration 610, loss = 4.23173649
# Iteration 611, loss = 4.23043016
# Iteration 612, loss = 4.22916593
# Iteration 613, loss = 4.22786586
# Iteration 614, loss = 4.22655143
# Iteration 615, loss = 4.22530104
# Iteration 616, loss = 4.22402098
# Iteration 617, loss = 4.22275767
# Iteration 618, loss = 4.22150586
# Iteration 619, loss = 4.22025414
# Iteration 620, loss = 4.21899007
# Iteration 621, loss = 4.21772740
# Iteration 622, loss = 4.21646388
# Iteration 623, loss = 4.21520062
# Iteration 624, loss = 4.21394203
# Iteration 625, loss = 4.21271361
# Iteration 626, loss = 4.21146898
# Iteration 627, loss = 4.21020822
# Iteration 628, loss = 4.20908674
# Iteration 629, loss = 4.20781427
# Iteration 630, loss = 4.20653442
# Iteration 631, loss = 4.20534794
# Iteration 632, loss = 4.20411854
# Iteration 633, loss = 4.20290283
# Iteration 634, loss = 4.20171944
# Iteration 635, loss = 4.20050367
# Iteration 636, loss = 4.19929101
# Iteration 637, loss = 4.19807176
# Iteration 638, loss = 4.19684551
# Iteration 639, loss = 4.19561332
# Iteration 640, loss = 4.19438826
# Iteration 641, loss = 4.19317669
# Iteration 642, loss = 4.19194861
# Iteration 643, loss = 4.19071460
# Iteration 644, loss = 4.18954115
# Iteration 645, loss = 4.18829968
# Iteration 646, loss = 4.18710787
# Iteration 647, loss = 4.18590027
# Iteration 648, loss = 4.18467594
# Iteration 649, loss = 4.18348655
# Iteration 650, loss = 4.18230733
# Iteration 651, loss = 4.18111915
# Iteration 652, loss = 4.17990880
# Iteration 653, loss = 4.17871823
# Iteration 654, loss = 4.17754256
# Iteration 655, loss = 4.17635364
# Iteration 656, loss = 4.17518266
# Iteration 657, loss = 4.17400981
# Iteration 658, loss = 4.17286422
# Iteration 659, loss = 4.17169760
# Iteration 660, loss = 4.17051007
# Iteration 661, loss = 4.16920083
# Iteration 662, loss = 4.16783945
# Iteration 663, loss = 4.16645561
# Iteration 664, loss = 4.16508634
# Iteration 665, loss = 4.16369118
# Iteration 666, loss = 4.16229444
# Iteration 667, loss = 4.16085963
# Iteration 668, loss = 4.15939635
# Iteration 669, loss = 4.15805418
# Iteration 670, loss = 4.15668551
# Iteration 671, loss = 4.15557820
# Iteration 672, loss = 4.15458061
# Iteration 673, loss = 4.15349612
# Iteration 674, loss = 4.15243314
# Iteration 675, loss = 4.15132968
# Iteration 676, loss = 4.15024688
# Iteration 677, loss = 4.14921395
# Iteration 678, loss = 4.14814668
# Iteration 679, loss = 4.14701505
# Iteration 680, loss = 4.14591050
# Iteration 681, loss = 4.14478017
# Iteration 682, loss = 4.14361406
# Iteration 683, loss = 4.14250717
# Iteration 684, loss = 4.14134057
# Iteration 685, loss = 4.14017389
# Iteration 686, loss = 4.13903012
# Iteration 687, loss = 4.13783294
# Iteration 688, loss = 4.13667129
# Iteration 689, loss = 4.13550478
# Iteration 690, loss = 4.13436166
# Iteration 691, loss = 4.13317514
# Iteration 692, loss = 4.13201520
# Iteration 693, loss = 4.13085855
# Iteration 694, loss = 4.12972749
# Iteration 695, loss = 4.12854739
# Iteration 696, loss = 4.12740803
# Iteration 697, loss = 4.12627184
# Iteration 698, loss = 4.12511050
# Iteration 699, loss = 4.12395256
# Iteration 700, loss = 4.12283652
# Iteration 701, loss = 4.12170185
# Iteration 702, loss = 4.12055029
# Iteration 703, loss = 4.11938910
# Iteration 704, loss = 4.11825423
# Iteration 705, loss = 4.11717390
# Iteration 706, loss = 4.11606822
# Iteration 707, loss = 4.11491120
# Iteration 708, loss = 4.11385705
# Iteration 709, loss = 4.11278327
# Iteration 710, loss = 4.11167378
# Iteration 711, loss = 4.11056971
# Iteration 712, loss = 4.10949864
# Iteration 713, loss = 4.10840853
# Iteration 714, loss = 4.10729213
# Iteration 715, loss = 4.10624658
# Iteration 716, loss = 4.10522944
# Iteration 717, loss = 4.10417171
# Iteration 718, loss = 4.10306366
# Iteration 719, loss = 4.10199886
# Iteration 720, loss = 4.10098626
# Iteration 721, loss = 4.09994726
# Iteration 722, loss = 4.09888408
# Iteration 723, loss = 4.09781905
# Iteration 724, loss = 4.09680562
# Iteration 725, loss = 4.09578582
# Iteration 726, loss = 4.09474439
# Iteration 727, loss = 4.09369135
# Iteration 728, loss = 4.09268648
# Iteration 729, loss = 4.09165995
# Iteration 730, loss = 4.09061436
# Iteration 731, loss = 4.08970236
# Iteration 732, loss = 4.08867192
# Iteration 733, loss = 4.08764922
# Iteration 734, loss = 4.08663908
# Iteration 735, loss = 4.08564915
# Iteration 736, loss = 4.08466206
# Iteration 737, loss = 4.08366268
# Iteration 738, loss = 4.08267687
# Iteration 739, loss = 4.08170742
# Iteration 740, loss = 4.08076195
# Iteration 741, loss = 4.07980848
# Iteration 742, loss = 4.07886029
# Iteration 743, loss = 4.07791228
# Iteration 744, loss = 4.07694615
# Iteration 745, loss = 4.07604190
# Iteration 746, loss = 4.07512388
# Iteration 747, loss = 4.07417291
# Iteration 748, loss = 4.07323499
# Iteration 749, loss = 4.07233605
# Iteration 750, loss = 4.07141123
# Iteration 751, loss = 4.07047668
# Iteration 752, loss = 4.06953907
# Iteration 753, loss = 4.06867507
# Iteration 754, loss = 4.06778853
# Iteration 755, loss = 4.06685359
# Iteration 756, loss = 4.06596283
# Iteration 757, loss = 4.06511336
# Iteration 758, loss = 4.06424981
# Iteration 759, loss = 4.06335039
# Iteration 760, loss = 4.06250804
# Iteration 761, loss = 4.06164760
# Iteration 762, loss = 4.06076542
# Iteration 763, loss = 4.05986362
# Iteration 764, loss = 4.05894490
# Iteration 765, loss = 4.05804610
# Iteration 766, loss = 4.05726085
# Iteration 767, loss = 4.05639683
# Iteration 768, loss = 4.05552764
# Iteration 769, loss = 4.05466469
# Iteration 770, loss = 4.05383933
# Iteration 771, loss = 4.05299629
# Iteration 772, loss = 4.05212134
# Iteration 773, loss = 4.05123377
# Iteration 774, loss = 4.05042355
# Iteration 775, loss = 4.04965595
# Iteration 776, loss = 4.04881329
# Iteration 777, loss = 4.04789765
# Iteration 778, loss = 4.04707362
# Iteration 779, loss = 4.04629844
# Iteration 780, loss = 4.04549564
# Iteration 781, loss = 4.04466274
# Iteration 782, loss = 4.04381691
# Iteration 783, loss = 4.04295408
# Iteration 784, loss = 4.04209878
# Iteration 785, loss = 4.04127373
# Iteration 786, loss = 4.04049218
# Iteration 787, loss = 4.03968871
# Iteration 788, loss = 4.03885039
# Iteration 789, loss = 4.03808237
# Iteration 790, loss = 4.03727694
# Iteration 791, loss = 4.03647359
# Iteration 792, loss = 4.03565441
# Iteration 793, loss = 4.03481047
# Iteration 794, loss = 4.03400827
# Iteration 795, loss = 4.03324631
# Iteration 796, loss = 4.03242204
# Iteration 797, loss = 4.03167776
# Iteration 798, loss = 4.03084140
# Iteration 799, loss = 4.03006632
# Iteration 800, loss = 4.02936746
# Iteration 801, loss = 4.02849708
# Iteration 802, loss = 4.02775625
# Iteration 803, loss = 4.02700513
# Iteration 804, loss = 4.02611871
# Iteration 805, loss = 4.02556749
# Iteration 806, loss = 4.02474820
# Iteration 807, loss = 4.02387587
# Iteration 808, loss = 4.02319523
# Iteration 809, loss = 4.02245051
# Iteration 810, loss = 4.02157546
# Iteration 811, loss = 4.02081168
# Iteration 812, loss = 4.02017346
# Iteration 813, loss = 4.01926232
# Iteration 814, loss = 4.01851152
# Iteration 815, loss = 4.01776497
# Iteration 816, loss = 4.01702374
# Iteration 817, loss = 4.01625761
# Iteration 818, loss = 4.01548727
# Iteration 819, loss = 4.01471277
# Iteration 820, loss = 4.01399055
# Iteration 821, loss = 4.01328069
# Iteration 822, loss = 4.01251119
# Iteration 823, loss = 4.01173579
# Iteration 824, loss = 4.01106394
# Iteration 825, loss = 4.01031048
# Iteration 826, loss = 4.00954296
# Iteration 827, loss = 4.00879903
# Iteration 828, loss = 4.00805925
# Iteration 829, loss = 4.00740756
# Iteration 830, loss = 4.00667827
# Iteration 831, loss = 4.00587953
# Iteration 832, loss = 4.00517021
# Iteration 833, loss = 4.00446323
# Iteration 834, loss = 4.00379797
# Iteration 835, loss = 4.00306307
# Iteration 836, loss = 4.00234801
# Iteration 837, loss = 4.00158101
# Iteration 838, loss = 4.00085299
# Iteration 839, loss = 4.00008091
# Iteration 840, loss = 3.99952904
# Iteration 841, loss = 3.99883654
# Iteration 842, loss = 3.99798381
# Iteration 843, loss = 3.99725712
# Iteration 844, loss = 3.99658266
# Iteration 845, loss = 3.99592149
# Iteration 846, loss = 3.99519663
# Iteration 847, loss = 3.99447378
# Iteration 848, loss = 3.99377667
# Iteration 849, loss = 3.99302502
# Iteration 850, loss = 3.99233312
# Iteration 851, loss = 3.99163655
# Iteration 852, loss = 3.99099065
# Iteration 853, loss = 3.99022179
# Iteration 854, loss = 3.98959259
# Iteration 855, loss = 3.98881197
# Iteration 856, loss = 3.98824429
# Iteration 857, loss = 3.98754389
# Iteration 858, loss = 3.98677531
# Iteration 859, loss = 3.98611661
# Iteration 860, loss = 3.98546037
# Iteration 861, loss = 3.98466816
# Iteration 862, loss = 3.98410893
# Iteration 863, loss = 3.98338015
# Iteration 864, loss = 3.98264087
# Iteration 865, loss = 3.98204374
# Iteration 866, loss = 3.98136885
# Iteration 867, loss = 3.98063910
# Iteration 868, loss = 3.97988830
# Iteration 869, loss = 3.97924292
# Iteration 870, loss = 3.97863666
# Iteration 871, loss = 3.97784203
# Iteration 872, loss = 3.97725304
# Iteration 873, loss = 3.97658190
# Iteration 874, loss = 3.97586867
# Iteration 875, loss = 3.97523236
# Iteration 876, loss = 3.97466044
# Iteration 877, loss = 3.97390489
# Iteration 878, loss = 3.97315792
# Iteration 879, loss = 3.97256682
# Iteration 880, loss = 3.97200813
# Iteration 881, loss = 3.97132182
# Iteration 882, loss = 3.97050207
# Iteration 883, loss = 3.96980205
# Iteration 884, loss = 3.96923774
# Iteration 885, loss = 3.96863253
# Iteration 886, loss = 3.96788270
# Iteration 887, loss = 3.96720699
# Iteration 888, loss = 3.96657063
# Iteration 889, loss = 3.96591469
# Iteration 890, loss = 3.96522692
# Iteration 891, loss = 3.96456070
# Iteration 892, loss = 3.96383877
# Iteration 893, loss = 3.96326112
# Iteration 894, loss = 3.96264187
# Iteration 895, loss = 3.96193903
# Iteration 896, loss = 3.96125671
# Iteration 897, loss = 3.96059306
# Iteration 898, loss = 3.95996049
# Iteration 899, loss = 3.95929694
# Iteration 900, loss = 3.95872624
# Iteration 901, loss = 3.95809256
# Iteration 902, loss = 3.95740914
# Iteration 903, loss = 3.95674466
# Iteration 904, loss = 3.95611031
# Iteration 905, loss = 3.95546222
# Iteration 906, loss = 3.95477211
# Iteration 907, loss = 3.95410183
# Iteration 908, loss = 3.95347263
# Iteration 909, loss = 3.95280013
# Iteration 910, loss = 3.95215833
# Iteration 911, loss = 3.95156630
# Iteration 912, loss = 3.95091719
# Iteration 913, loss = 3.95025439
# Iteration 914, loss = 3.94961880
# Iteration 915, loss = 3.94898849
# Iteration 916, loss = 3.94833007
# Iteration 917, loss = 3.94769509
# Iteration 918, loss = 3.94708224
# Iteration 919, loss = 3.94649364
# Iteration 920, loss = 3.94586806
# Iteration 921, loss = 3.94524652
# Iteration 922, loss = 3.94458232
# Iteration 923, loss = 3.94398395
# Iteration 924, loss = 3.94336548
# Iteration 925, loss = 3.94273793
# Iteration 926, loss = 3.94209158
# Iteration 927, loss = 3.94144537
# Iteration 928, loss = 3.94086507
# Iteration 929, loss = 3.94028764
# Iteration 930, loss = 3.93964645
# Iteration 931, loss = 3.93900260
# Iteration 932, loss = 3.93844765
# Iteration 933, loss = 3.93786286
# Iteration 934, loss = 3.93719261
# Iteration 935, loss = 3.93662829
# Iteration 936, loss = 3.93605328
# Iteration 937, loss = 3.93540680
# Iteration 938, loss = 3.93475384
# Iteration 939, loss = 3.93413485
# Iteration 940, loss = 3.93355702
# Iteration 941, loss = 3.93293159
# Iteration 942, loss = 3.93231069
# Iteration 943, loss = 3.93168960
# Iteration 944, loss = 3.93110638
# Iteration 945, loss = 3.93049767
# Iteration 946, loss = 3.92993790
# Iteration 947, loss = 3.92929996
# Iteration 948, loss = 3.92869718
# Iteration 949, loss = 3.92811684
# Iteration 950, loss = 3.92748420
# Iteration 951, loss = 3.92693973
# Iteration 952, loss = 3.92632001
# Iteration 953, loss = 3.92571308
# Iteration 954, loss = 3.92515842
# Iteration 955, loss = 3.92453387
# Iteration 956, loss = 3.92394941
# Iteration 957, loss = 3.92334862
# Iteration 958, loss = 3.92279438
# Iteration 959, loss = 3.92219544
# Iteration 960, loss = 3.92159551
# Iteration 961, loss = 3.92097932
# Iteration 962, loss = 3.92038975
# Iteration 963, loss = 3.91980034
# Iteration 964, loss = 3.91918293
# Iteration 965, loss = 3.91863365
# Iteration 966, loss = 3.91805970
# Iteration 967, loss = 3.91748824
# Iteration 968, loss = 3.91687397
# Iteration 969, loss = 3.91632454
# Iteration 970, loss = 3.91574267
# Iteration 971, loss = 3.91515225
# Iteration 972, loss = 3.91454394
# Iteration 973, loss = 3.91396034
# Iteration 974, loss = 3.91341305
# Iteration 975, loss = 3.91285101
# Iteration 976, loss = 3.91223802
# Iteration 977, loss = 3.91169465
# Iteration 978, loss = 3.91107922
# Iteration 979, loss = 3.91050708
# Iteration 980, loss = 3.90992944
# Iteration 981, loss = 3.90934969
# Iteration 982, loss = 3.90880959
# Iteration 983, loss = 3.90821183
# Iteration 984, loss = 3.90763973
# Iteration 985, loss = 3.90707233
# Iteration 986, loss = 3.90651789
# Iteration 987, loss = 3.90593377
# Iteration 988, loss = 3.90535552
# Iteration 989, loss = 3.90480490
# Iteration 990, loss = 3.90422761
# Iteration 991, loss = 3.90362192
# Iteration 992, loss = 3.90313860
# Iteration 993, loss = 3.90252187
# Iteration 994, loss = 3.90201947
# Iteration 995, loss = 3.90141872
# Iteration 996, loss = 3.90087978
# Iteration 997, loss = 3.90030261
# Iteration 998, loss = 3.89978572
# Iteration 999, loss = 3.89916725
# Iteration 1000, loss = 3.89859571
# Iteration 1001, loss = 3.89803627
# Iteration 1002, loss = 3.89746031
# Iteration 1003, loss = 3.89690699
# Iteration 1004, loss = 3.89641320
# Iteration 1005, loss = 3.89584207
# Iteration 1006, loss = 3.89528484
# Iteration 1007, loss = 3.89474418
# Iteration 1008, loss = 3.89415076
# Iteration 1009, loss = 3.89360149
# Iteration 1010, loss = 3.89309605
# Iteration 1011, loss = 3.89250227
# Iteration 1012, loss = 3.89191018
# Iteration 1013, loss = 3.89138328
# Iteration 1014, loss = 3.89086102
# Iteration 1015, loss = 3.89029985
# Iteration 1016, loss = 3.88976140
# Iteration 1017, loss = 3.88917468
# Iteration 1018, loss = 3.88862058
# Iteration 1019, loss = 3.88804517
# Iteration 1020, loss = 3.88750781
# Iteration 1021, loss = 3.88696000
# Iteration 1022, loss = 3.88644446
# Iteration 1023, loss = 3.88588131
# Iteration 1024, loss = 3.88531422
# Iteration 1025, loss = 3.88474441
# Iteration 1026, loss = 3.88418450
# Iteration 1027, loss = 3.88366945
# Iteration 1028, loss = 3.88310710
# Iteration 1029, loss = 3.88256473
# Iteration 1030, loss = 3.88202842
# Iteration 1031, loss = 3.88149561
# Iteration 1032, loss = 3.88092262
# Iteration 1033, loss = 3.88040250
# Iteration 1034, loss = 3.87984406
# Iteration 1035, loss = 3.87934295
# Iteration 1036, loss = 3.87880516
# Iteration 1037, loss = 3.87824088
# Iteration 1038, loss = 3.87774409
# Iteration 1039, loss = 3.87716679
# Iteration 1040, loss = 3.87664183
# Iteration 1041, loss = 3.87613612
# Iteration 1042, loss = 3.87559278
# Iteration 1043, loss = 3.87503200
# Iteration 1044, loss = 3.87450395
# Iteration 1045, loss = 3.87399838
# Iteration 1046, loss = 3.87344949
# Iteration 1047, loss = 3.87288069
# Iteration 1048, loss = 3.87233993
# Iteration 1049, loss = 3.87179582
# Iteration 1050, loss = 3.87126942
# Iteration 1051, loss = 3.87075142
# Iteration 1052, loss = 3.87027957
# Iteration 1053, loss = 3.86970116
# Iteration 1054, loss = 3.86917701
# Iteration 1055, loss = 3.86864547
# Iteration 1056, loss = 3.86814491
# Iteration 1057, loss = 3.86763195
# Iteration 1058, loss = 3.86710938
# Iteration 1059, loss = 3.86659755
# Iteration 1060, loss = 3.86606158
# Iteration 1061, loss = 3.86553376
# Iteration 1062, loss = 3.86503724
# Iteration 1063, loss = 3.86449215
# Iteration 1064, loss = 3.86395618
# Iteration 1065, loss = 3.86341552
# Iteration 1066, loss = 3.86288714
# Iteration 1067, loss = 3.86238631
# Iteration 1068, loss = 3.86184605
# Iteration 1069, loss = 3.86134300
# Iteration 1070, loss = 3.86080170
# Iteration 1071, loss = 3.86028895
# Iteration 1072, loss = 3.85976001
# Iteration 1073, loss = 3.85924912
# Iteration 1074, loss = 3.85871259
# Iteration 1075, loss = 3.85826395
# Iteration 1076, loss = 3.85773963
# Iteration 1077, loss = 3.85722997
# Iteration 1078, loss = 3.85672562
# Iteration 1079, loss = 3.85619129
# Iteration 1080, loss = 3.85564477
# Iteration 1081, loss = 3.85519973
# Iteration 1082, loss = 3.85466049
# Iteration 1083, loss = 3.85414557
# Iteration 1084, loss = 3.85363407
# Iteration 1085, loss = 3.85317570
# Iteration 1086, loss = 3.85270770
# Iteration 1087, loss = 3.85218467
# Iteration 1088, loss = 3.85162866
# Iteration 1089, loss = 3.85111946
# Iteration 1090, loss = 3.85058997
# Iteration 1091, loss = 3.85013969
# Iteration 1092, loss = 3.84965982
# Iteration 1093, loss = 3.84912368
# Iteration 1094, loss = 3.84860464
# Iteration 1095, loss = 3.84813871
# Iteration 1096, loss = 3.84765676
# Iteration 1097, loss = 3.84711147
# Iteration 1098, loss = 3.84662544
# Iteration 1099, loss = 3.84615787
# Iteration 1100, loss = 3.84565808
# Iteration 1101, loss = 3.84511387
# Iteration 1102, loss = 3.84455840
# Iteration 1103, loss = 3.84409319
# Iteration 1104, loss = 3.84359687
# Iteration 1105, loss = 3.84308159
# Iteration 1106, loss = 3.84260615
# Iteration 1107, loss = 3.84207995
# Iteration 1108, loss = 3.84161640
# Iteration 1109, loss = 3.84110001
# Iteration 1110, loss = 3.84060400
# Iteration 1111, loss = 3.84011501
# Iteration 1112, loss = 3.83965033
# Iteration 1113, loss = 3.83916042
# Iteration 1114, loss = 3.83867854
# Iteration 1115, loss = 3.83816200
# Iteration 1116, loss = 3.83764565
# Iteration 1117, loss = 3.83715121
# Iteration 1118, loss = 3.83665608
# Iteration 1119, loss = 3.83622547
# Iteration 1120, loss = 3.83566597
# Iteration 1121, loss = 3.83518777
# Iteration 1122, loss = 3.83473621
# Iteration 1123, loss = 3.83422758
# Iteration 1124, loss = 3.83377546
# Iteration 1125, loss = 3.83324774
# Iteration 1126, loss = 3.83277843
# Iteration 1127, loss = 3.83233212
# Iteration 1128, loss = 3.83182500
# Iteration 1129, loss = 3.83135555
# Iteration 1130, loss = 3.83087067
# Iteration 1131, loss = 3.83039240
# Iteration 1132, loss = 3.82993355
# Iteration 1133, loss = 3.82943047
# Iteration 1134, loss = 3.82895676
# Iteration 1135, loss = 3.82848908
# Iteration 1136, loss = 3.82798851
# Iteration 1137, loss = 3.82754068
# Iteration 1138, loss = 3.82706527
# Iteration 1139, loss = 3.82658232
# Iteration 1140, loss = 3.82615774
# Iteration 1141, loss = 3.82566601
# Iteration 1142, loss = 3.82518095
# Iteration 1143, loss = 3.82472386
# Iteration 1144, loss = 3.82424129
# Iteration 1145, loss = 3.82382034
# Iteration 1146, loss = 3.82329232
# Iteration 1147, loss = 3.82286190
# Iteration 1148, loss = 3.82239853
# Iteration 1149, loss = 3.82191909
# Iteration 1150, loss = 3.82145856
# Iteration 1151, loss = 3.82096496
# Iteration 1152, loss = 3.82048829
# Iteration 1153, loss = 3.82002488
# Iteration 1154, loss = 3.81960481
# Iteration 1155, loss = 3.81908888
# Iteration 1156, loss = 3.81869624
# Iteration 1157, loss = 3.81819824
# Iteration 1158, loss = 3.81776321
# Iteration 1159, loss = 3.81732399
# Iteration 1160, loss = 3.81691322
# Iteration 1161, loss = 3.81637150
# Iteration 1162, loss = 3.81591933
# Iteration 1163, loss = 3.81547132
# Iteration 1164, loss = 3.81498013
# Iteration 1165, loss = 3.81453330
# Iteration 1166, loss = 3.81408192
# Iteration 1167, loss = 3.81359853
# Iteration 1168, loss = 3.81312530
# Iteration 1169, loss = 3.81267366
# Iteration 1170, loss = 3.81220725
# Iteration 1171, loss = 3.81174742
# Iteration 1172, loss = 3.81133330
# Iteration 1173, loss = 3.81087148
# Iteration 1174, loss = 3.81042085
# Iteration 1175, loss = 3.80996225
# Iteration 1176, loss = 3.80950496
# Iteration 1177, loss = 3.80904730
# Iteration 1178, loss = 3.80861202
# Iteration 1179, loss = 3.80815908
# Iteration 1180, loss = 3.80768766
# Iteration 1181, loss = 3.80730429
# Iteration 1182, loss = 3.80681316
# Iteration 1183, loss = 3.80636286
# Iteration 1184, loss = 3.80594137
# Iteration 1185, loss = 3.80555637
# Iteration 1186, loss = 3.80502549
# Iteration 1187, loss = 3.80457054
# Iteration 1188, loss = 3.80412954
# Iteration 1189, loss = 3.80365800
# Iteration 1190, loss = 3.80321903
# Iteration 1191, loss = 3.80280978
# Iteration 1192, loss = 3.80234610
# Iteration 1193, loss = 3.80188236
# Iteration 1194, loss = 3.80141978
# Iteration 1195, loss = 3.80102464
# Iteration 1196, loss = 3.80055370
# Iteration 1197, loss = 3.80009211
# Iteration 1198, loss = 3.79963870
# Iteration 1199, loss = 3.79920881
# Iteration 1200, loss = 3.79875326
# Iteration 1201, loss = 3.79835614
# Iteration 1202, loss = 3.79789183
# Iteration 1203, loss = 3.79747339
# Iteration 1204, loss = 3.79704626
# Iteration 1205, loss = 3.79659163
# Iteration 1206, loss = 3.79611659
# Iteration 1207, loss = 3.79576109
# Iteration 1208, loss = 3.79524622
# Iteration 1209, loss = 3.79478357
# Iteration 1210, loss = 3.79445285
# Iteration 1211, loss = 3.79396306
# Iteration 1212, loss = 3.79351676
# Iteration 1213, loss = 3.79318357
# Iteration 1214, loss = 3.79277367
# Iteration 1215, loss = 3.79227309
# Iteration 1216, loss = 3.79183679
# Iteration 1217, loss = 3.79146293
# Iteration 1218, loss = 3.79102167
# Iteration 1219, loss = 3.79051051
# Iteration 1220, loss = 3.79004561
# Iteration 1221, loss = 3.78968542
# Iteration 1222, loss = 3.78917139
# Iteration 1223, loss = 3.78871905
# Iteration 1224, loss = 3.78830702
# Iteration 1225, loss = 3.78788871
# Iteration 1226, loss = 3.78748415
# Iteration 1227, loss = 3.78708751
# Iteration 1228, loss = 3.78662843
# Iteration 1229, loss = 3.78614200
# Iteration 1230, loss = 3.78575803
# Iteration 1231, loss = 3.78530028
# Iteration 1232, loss = 3.78489570
# Iteration 1233, loss = 3.78446788
# Iteration 1234, loss = 3.78405624
# Iteration 1235, loss = 3.78363340
# Iteration 1236, loss = 3.78316497
# Iteration 1237, loss = 3.78276921
# Iteration 1238, loss = 3.78235265
# Iteration 1239, loss = 3.78191225
# Iteration 1240, loss = 3.78145923
# Iteration 1241, loss = 3.78107807
# Iteration 1242, loss = 3.78057908
# Iteration 1243, loss = 3.78018039
# Iteration 1244, loss = 3.77972754
# Iteration 1245, loss = 3.77931114
# Iteration 1246, loss = 3.77890594
# Iteration 1247, loss = 3.77846996
# Iteration 1248, loss = 3.77806228
# Iteration 1249, loss = 3.77767312
# Iteration 1250, loss = 3.77721234
# Iteration 1251, loss = 3.77684105
# Iteration 1252, loss = 3.77635761
# Iteration 1253, loss = 3.77594672
# Iteration 1254, loss = 3.77552209
# Iteration 1255, loss = 3.77508972
# Iteration 1256, loss = 3.77467510
# Iteration 1257, loss = 3.77426177
# Iteration 1258, loss = 3.77392859
# Iteration 1259, loss = 3.77341948
# Iteration 1260, loss = 3.77302211
# Iteration 1261, loss = 3.77270134
# Iteration 1262, loss = 3.77225070
# Iteration 1263, loss = 3.77188731
# Iteration 1264, loss = 3.77151684
# Iteration 1265, loss = 3.77109718
# Iteration 1266, loss = 3.77063195
# Iteration 1267, loss = 3.77019001
# Iteration 1268, loss = 3.76979444
# Iteration 1269, loss = 3.76935380
# Iteration 1270, loss = 3.76891878
# Iteration 1271, loss = 3.76848747
# Iteration 1272, loss = 3.76810684
# Iteration 1273, loss = 3.76766508
# Iteration 1274, loss = 3.76722046
# Iteration 1275, loss = 3.76681899
# Iteration 1276, loss = 3.76640897
# Iteration 1277, loss = 3.76598113
# Iteration 1278, loss = 3.76558864
# Iteration 1279, loss = 3.76526180
# Iteration 1280, loss = 3.76479886
# Iteration 1281, loss = 3.76436561
# Iteration 1282, loss = 3.76394773
# Iteration 1283, loss = 3.76357610
# Iteration 1284, loss = 3.76311813
# Iteration 1285, loss = 3.76274072
# Iteration 1286, loss = 3.76234080
# Iteration 1287, loss = 3.76190954
# Iteration 1288, loss = 3.76150392
# Iteration 1289, loss = 3.76108294
# Iteration 1290, loss = 3.76069461
# Iteration 1291, loss = 3.76029980
# Iteration 1292, loss = 3.75988697
# Iteration 1293, loss = 3.75944925
# Iteration 1294, loss = 3.75908848
# Iteration 1295, loss = 3.75866478
# Iteration 1296, loss = 3.75831718
# Iteration 1297, loss = 3.75782888
# Iteration 1298, loss = 3.75745276
# Iteration 1299, loss = 3.75706729
# Iteration 1300, loss = 3.75672777
# Iteration 1301, loss = 3.75627178
# Iteration 1302, loss = 3.75584256
# Iteration 1303, loss = 3.75544004
# Iteration 1304, loss = 3.75507000
# Iteration 1305, loss = 3.75467667
# Iteration 1306, loss = 3.75423529
# Iteration 1307, loss = 3.75383752
# Iteration 1308, loss = 3.75344940
# Iteration 1309, loss = 3.75304757
# Iteration 1310, loss = 3.75264138
# Iteration 1311, loss = 3.75220875
# Iteration 1312, loss = 3.75186506
# Iteration 1313, loss = 3.75142983
# Iteration 1314, loss = 3.75103041
# Iteration 1315, loss = 3.75062733
# Iteration 1316, loss = 3.75029543
# Iteration 1317, loss = 3.74985296
# Iteration 1318, loss = 3.74944533
# Iteration 1319, loss = 3.74903837
# Iteration 1320, loss = 3.74862612
# Iteration 1321, loss = 3.74826537
# Iteration 1322, loss = 3.74785293
# Iteration 1323, loss = 3.74747181
# Iteration 1324, loss = 3.74707533
# Iteration 1325, loss = 3.74666624
# Iteration 1326, loss = 3.74626553
# Iteration 1327, loss = 3.74586707
# Iteration 1328, loss = 3.74547285
# Iteration 1329, loss = 3.74509611
# Iteration 1330, loss = 3.74473168
# Iteration 1331, loss = 3.74429490
# Iteration 1332, loss = 3.74394340
# Iteration 1333, loss = 3.74354419
# Iteration 1334, loss = 3.74319328
# Iteration 1335, loss = 3.74273569
# Iteration 1336, loss = 3.74238031
# Iteration 1337, loss = 3.74197887
# Iteration 1338, loss = 3.74157418
# Iteration 1339, loss = 3.74118752
# Iteration 1340, loss = 3.74080591
# Iteration 1341, loss = 3.74040317
# Iteration 1342, loss = 3.74003441
# Iteration 1343, loss = 3.73965095
# Iteration 1344, loss = 3.73923585
# Iteration 1345, loss = 3.73888616
# Iteration 1346, loss = 3.73849369
# Iteration 1347, loss = 3.73807896
# Iteration 1348, loss = 3.73774171
# Iteration 1349, loss = 3.73736824
# Iteration 1350, loss = 3.73697474
# Iteration 1351, loss = 3.73662839
# Iteration 1352, loss = 3.73615753
# Iteration 1353, loss = 3.73576012
# Iteration 1354, loss = 3.73547820
# Iteration 1355, loss = 3.73498324
# Iteration 1356, loss = 3.73463574
# Iteration 1357, loss = 3.73438756
# Iteration 1358, loss = 3.73400884
# Iteration 1359, loss = 3.73362803
# Iteration 1360, loss = 3.73325545
# Iteration 1361, loss = 3.73282499
# Iteration 1362, loss = 3.73238112
# Iteration 1363, loss = 3.73198747
# Iteration 1364, loss = 3.73165563
# Iteration 1365, loss = 3.73117554
# Iteration 1366, loss = 3.73092171
# Iteration 1367, loss = 3.73052849
# Iteration 1368, loss = 3.73004719
# Iteration 1369, loss = 3.72968752
# Iteration 1370, loss = 3.72934419
# Iteration 1371, loss = 3.72899792
# Iteration 1372, loss = 3.72864384
# Iteration 1373, loss = 3.72825783
# Iteration 1374, loss = 3.72782503
# Iteration 1375, loss = 3.72743978
# Iteration 1376, loss = 3.72713816
# Iteration 1377, loss = 3.72665488
# Iteration 1378, loss = 3.72625939
# Iteration 1379, loss = 3.72591823
# Iteration 1380, loss = 3.72550386
# Iteration 1381, loss = 3.72514512
# Iteration 1382, loss = 3.72478021
# Iteration 1383, loss = 3.72440424
# Iteration 1384, loss = 3.72401712
# Iteration 1385, loss = 3.72365254
# Iteration 1386, loss = 3.72331840
# Iteration 1387, loss = 3.72292741
# Iteration 1388, loss = 3.72251905
# Iteration 1389, loss = 3.72213541
# Iteration 1390, loss = 3.72184552
# Iteration 1391, loss = 3.72136455
# Iteration 1392, loss = 3.72098296
# Iteration 1393, loss = 3.72062580
# Iteration 1394, loss = 3.72022691
# Iteration 1395, loss = 3.71982083
# Iteration 1396, loss = 3.71943688
# Iteration 1397, loss = 3.71904158
# Iteration 1398, loss = 3.71868126
# Iteration 1399, loss = 3.71828707
# Iteration 1400, loss = 3.71791209
# Iteration 1401, loss = 3.71754375
# Iteration 1402, loss = 3.71715620
# Iteration 1403, loss = 3.71672963
# Iteration 1404, loss = 3.71641800
# Iteration 1405, loss = 3.71613536
# Iteration 1406, loss = 3.71561617
# Iteration 1407, loss = 3.71527588
# Iteration 1408, loss = 3.71504898
# Iteration 1409, loss = 3.71462188
# Iteration 1410, loss = 3.71422184
# Iteration 1411, loss = 3.71382706
# Iteration 1412, loss = 3.71342057
# Iteration 1413, loss = 3.71302632
# Iteration 1414, loss = 3.71257569
# Iteration 1415, loss = 3.71218400
# Iteration 1416, loss = 3.71187988
# Iteration 1417, loss = 3.71143923
# Iteration 1418, loss = 3.71103753
# Iteration 1419, loss = 3.71070236
# Iteration 1420, loss = 3.71044361
# Iteration 1421, loss = 3.70993779
# Iteration 1422, loss = 3.70954789
# Iteration 1423, loss = 3.70914195
# Iteration 1424, loss = 3.70876845
# Iteration 1425, loss = 3.70836487
# Iteration 1426, loss = 3.70807307
# Iteration 1427, loss = 3.70763755
# Iteration 1428, loss = 3.70729642
# Iteration 1429, loss = 3.70698339
# Iteration 1430, loss = 3.70653811
# Iteration 1431, loss = 3.70614979
# Iteration 1432, loss = 3.70579242
# Iteration 1433, loss = 3.70541323
# Iteration 1434, loss = 3.70502379
# Iteration 1435, loss = 3.70463448
# Iteration 1436, loss = 3.70421727
# Iteration 1437, loss = 3.70382779
# Iteration 1438, loss = 3.70346391
# Iteration 1439, loss = 3.70311480
# Iteration 1440, loss = 3.70273772
# Iteration 1441, loss = 3.70234415
# Iteration 1442, loss = 3.70194265
# Iteration 1443, loss = 3.70159799
# Iteration 1444, loss = 3.70119853
# ...
# Iteration 1939, loss = 3.54017740
# Iteration 1940, loss = 3.53992697
# Iteration 1941, loss = 3.53956908
# Iteration 1942, loss = 3.53940430
# Iteration 1943, loss = 3.53903112
# Iteration 1944, loss = 3.53872059
# Iteration 1945, loss = 3.53851041
# Iteration 1946, loss = 3.53821383
# Iteration 1947, loss = 3.53815928
# Iteration 1948, loss = 3.53777732
# Iteration 1949, loss = 3.53741971
# Iteration 1950, loss = 3.53718276
# Iteration 1951, loss = 3.53704853
# Iteration 1952, loss = 3.53653664
# Iteration 1953, loss = 3.53621214
# Iteration 1954, loss = 3.53613662
# Iteration 1955, loss = 3.53581360
# Iteration 1956, loss = 3.53535567
# Iteration 1957, loss = 3.53536500
# Iteration 1958, loss = 3.53484271
# Iteration 1959, loss = 3.53463719
# Iteration 1960, loss = 3.53454748
# Iteration 1961, loss = 3.53425792
# Iteration 1962, loss = 3.53398360
# Iteration 1963, loss = 3.53373559
# Iteration 1964, loss = 3.53348718
# Iteration 1965, loss = 3.53311712
# Iteration 1966, loss = 3.53270308
# Iteration 1967, loss = 3.53226481
# Iteration 1968, loss = 3.53209838
# Iteration 1969, loss = 3.53186596
# Iteration 1970, loss = 3.53155212
# Iteration 1971, loss = 3.53125032
# Iteration 1972, loss = 3.53082805
# Iteration 1973, loss = 3.53038653
# Iteration 1974, loss = 3.53022299
# Iteration 1975, loss = 3.53000451
# Iteration 1976, loss = 3.52979352
# Iteration 1977, loss = 3.52945845
# Iteration 1978, loss = 3.52909675
# Iteration 1979, loss = 3.52884159
# Iteration 1980, loss = 3.52855383
# Iteration 1981, loss = 3.52833453
# Iteration 1982, loss = 3.52808687
# Iteration 1983, loss = 3.52776022
# Iteration 1984, loss = 3.52741169
# Iteration 1985, loss = 3.52704852
# Iteration 1986, loss = 3.52672361
# Iteration 1987, loss = 3.52637489
# Iteration 1988, loss = 3.52610019
# Iteration 1989, loss = 3.52582459
# Iteration 1990, loss = 3.52552839
# Iteration 1991, loss = 3.52519082
# Iteration 1992, loss = 3.52484549
# Iteration 1993, loss = 3.52459815
# Iteration 1994, loss = 3.52422775
# Iteration 1995, loss = 3.52394157
# Iteration 1996, loss = 3.52367447
# Iteration 1997, loss = 3.52337101
# Iteration 1998, loss = 3.52305822
# Iteration 1999, loss = 3.52272301
# Iteration 2000, loss = 3.52240051
# Iteration 2001, loss = 3.52207100
# Iteration 2002, loss = 3.52181444
# Iteration 2003, loss = 3.52168916
# Iteration 2004, loss = 3.52143730
# Iteration 2005, loss = 3.52096518
# Iteration 2006, loss = 3.52059346
# Iteration 2007, loss = 3.52031423
# Iteration 2008, loss = 3.51997064
# Iteration 2009, loss = 3.51968762
# Iteration 2010, loss = 3.51947249
# Iteration 2011, loss = 3.51933684
# Iteration 2012, loss = 3.51901670
# Iteration 2013, loss = 3.51851612
# Iteration 2014, loss = 3.51811536
# Iteration 2015, loss = 3.51787212
# Iteration 2016, loss = 3.51753492
# Iteration 2017, loss = 3.51727410
# Iteration 2018, loss = 3.51698671
# Iteration 2019, loss = 3.51665417
# Iteration 2020, loss = 3.51641303
# Iteration 2021, loss = 3.51614309
# Iteration 2022, loss = 3.51576193
# Iteration 2023, loss = 3.51534321
# Iteration 2024, loss = 3.51509612
# Iteration 2025, loss = 3.51481117
# Iteration 2026, loss = 3.51466561
# Iteration 2027, loss = 3.51432625
# Iteration 2028, loss = 3.51415225
# Iteration 2029, loss = 3.51383534
# Iteration 2030, loss = 3.51339231
# Iteration 2031, loss = 3.51305875
# Iteration 2032, loss = 3.51307111
# Iteration 2033, loss = 3.51254389
# Iteration 2034, loss = 3.51240098
# Iteration 2035, loss = 3.51213488
# Iteration 2036, loss = 3.51174003
# Iteration 2037, loss = 3.51138010
# Iteration 2038, loss = 3.51135709
# Iteration 2039, loss = 3.51101649
# Iteration 2040, loss = 3.51052172
# Iteration 2041, loss = 3.51036982
# Iteration 2042, loss = 3.51016727
# Iteration 2043, loss = 3.50980065
# Iteration 2044, loss = 3.50941397
# Iteration 2045, loss = 3.50955219
# Iteration 2046, loss = 3.50886633
# Iteration 2047, loss = 3.50868622
# Iteration 2048, loss = 3.50839005
# Iteration 2049, loss = 3.50804401
# Iteration 2050, loss = 3.50795231
# Iteration 2051, loss = 3.50748057
# Iteration 2052, loss = 3.50733752
# Iteration 2053, loss = 3.50702330
# Iteration 2054, loss = 3.50659925
# Iteration 2055, loss = 3.50635774
# Iteration 2056, loss = 3.50611493
# Iteration 2057, loss = 3.50581763
# Iteration 2058, loss = 3.50554888
# Iteration 2059, loss = 3.50533204
# Iteration 2060, loss = 3.50504880
# Iteration 2061, loss = 3.50468900
# Iteration 2062, loss = 3.50460706
# Iteration 2063, loss = 3.50424764
# Iteration 2064, loss = 3.50397250
# Iteration 2065, loss = 3.50363435
# Iteration 2066, loss = 3.50335831
# Iteration 2067, loss = 3.50323647
# Iteration 2068, loss = 3.50286988
# Iteration 2069, loss = 3.50258160
# Iteration 2070, loss = 3.50234329
# Iteration 2071, loss = 3.50200657
# Iteration 2072, loss = 3.50177028
# Iteration 2073, loss = 3.50151244
# Iteration 2074, loss = 3.50130403
# Iteration 2075, loss = 3.50098037
# Iteration 2076, loss = 3.50071904
# Iteration 2077, loss = 3.50051726
# Iteration 2078, loss = 3.50021058
# Iteration 2079, loss = 3.49982792
# Iteration 2080, loss = 3.49963848
# Iteration 2081, loss = 3.49935785
# Iteration 2082, loss = 3.49928474
# Iteration 2083, loss = 3.49887229
# Iteration 2084, loss = 3.49870061
# Iteration 2085, loss = 3.49838196
# Iteration 2086, loss = 3.49808550
# Iteration 2087, loss = 3.49785968
# Iteration 2088, loss = 3.49759221
# Iteration 2089, loss = 3.49730193
# Iteration 2090, loss = 3.49721193
# Iteration 2091, loss = 3.49690344
# Iteration 2092, loss = 3.49654591
# Iteration 2093, loss = 3.49629622
# Iteration 2094, loss = 3.49617197
# Iteration 2095, loss = 3.49576960
# Iteration 2096, loss = 3.49568037
# Iteration 2097, loss = 3.49538025
# Iteration 2098, loss = 3.49508189
# Iteration 2099, loss = 3.49483445
# Iteration 2100, loss = 3.49455938
# Iteration 2101, loss = 3.49420427
# Iteration 2102, loss = 3.49401169
# Iteration 2103, loss = 3.49384625
# Iteration 2104, loss = 3.49344004
# Iteration 2105, loss = 3.49334283
# Iteration 2106, loss = 3.49311591
# Iteration 2107, loss = 3.49287859
# Iteration 2108, loss = 3.49251847
# Iteration 2109, loss = 3.49222380
# Iteration 2110, loss = 3.49200714
# Iteration 2111, loss = 3.49194032
# Iteration 2112, loss = 3.49166596
# Iteration 2113, loss = 3.49133135
# Iteration 2114, loss = 3.49110237
# Iteration 2115, loss = 3.49080551
# Iteration 2116, loss = 3.49054403
# Iteration 2117, loss = 3.49025322
# Iteration 2118, loss = 3.49005809
# Iteration 2119, loss = 3.48974920
# Iteration 2120, loss = 3.48947335
# Iteration 2121, loss = 3.48920196
# Iteration 2122, loss = 3.48926402
# Iteration 2123, loss = 3.48896911
# Iteration 2124, loss = 3.48888782
# Iteration 2125, loss = 3.48847411
# Iteration 2126, loss = 3.48812049
# Iteration 2127, loss = 3.48771979
# Iteration 2128, loss = 3.48754249
# Iteration 2129, loss = 3.48737041
# Iteration 2130, loss = 3.48712682
# Iteration 2131, loss = 3.48686869
# Iteration 2132, loss = 3.48656731
# Iteration 2133, loss = 3.48644795
# Iteration 2134, loss = 3.48629842
# Iteration 2135, loss = 3.48594424
# Iteration 2136, loss = 3.48595866
# Iteration 2137, loss = 3.48563084
# Iteration 2138, loss = 3.48516911
# Iteration 2139, loss = 3.48506324
# Iteration 2140, loss = 3.48491449
# Iteration 2141, loss = 3.48448990
# Iteration 2142, loss = 3.48457131
# Iteration 2143, loss = 3.48443000
# Iteration 2144, loss = 3.48392054
# Iteration 2145, loss = 3.48354361
# Iteration 2146, loss = 3.48363374
# Iteration 2147, loss = 3.48302609
# Iteration 2148, loss = 3.48281509
# Iteration 2149, loss = 3.48271155
# Iteration 2150, loss = 3.48250870
# Iteration 2151, loss = 3.48233185
# Iteration 2152, loss = 3.48198564
# Iteration 2153, loss = 3.48163973
# Iteration 2154, loss = 3.48148057
# Iteration 2155, loss = 3.48128853
# Iteration 2156, loss = 3.48097435
# Iteration 2157, loss = 3.48079152
# Iteration 2158, loss = 3.48071590
# Iteration 2159, loss = 3.48036713
# Iteration 2160, loss = 3.48020759
# Iteration 2161, loss = 3.47974250
# Iteration 2162, loss = 3.47961724
# Iteration 2163, loss = 3.47924799
# Iteration 2164, loss = 3.47902310
# Iteration 2165, loss = 3.47880968
# Iteration 2166, loss = 3.47857546
# Iteration 2167, loss = 3.47835190
# Iteration 2168, loss = 3.47812797
# Iteration 2169, loss = 3.47791269
# Iteration 2170, loss = 3.47755283
# Iteration 2171, loss = 3.47737291
# Iteration 2172, loss = 3.47712589
# Iteration 2173, loss = 3.47690609
# Iteration 2174, loss = 3.47659917
# Iteration 2175, loss = 3.47647568
# Iteration 2176, loss = 3.47621036
# Iteration 2177, loss = 3.47604123
# Iteration 2178, loss = 3.47574909
# Iteration 2179, loss = 3.47545412
# Iteration 2180, loss = 3.47520979
# Iteration 2181, loss = 3.47494686
# Iteration 2182, loss = 3.47473152
# Iteration 2183, loss = 3.47448733
# Iteration 2184, loss = 3.47431204
# Iteration 2185, loss = 3.47412978
# Iteration 2186, loss = 3.47396839
# Iteration 2187, loss = 3.47362873
# Iteration 2188, loss = 3.47344404
# Iteration 2189, loss = 3.47322465
# Iteration 2190, loss = 3.47306911
# Iteration 2191, loss = 3.47284521
# Iteration 2192, loss = 3.47262112
# Iteration 2193, loss = 3.47225055
# Iteration 2194, loss = 3.47226168
# Iteration 2195, loss = 3.47230517
# Iteration 2196, loss = 3.47157275
# Iteration 2197, loss = 3.47170805
# Iteration 2198, loss = 3.47153268
# Iteration 2199, loss = 3.47119575
# Iteration 2200, loss = 3.47081688
# Iteration 2201, loss = 3.47052359
# Iteration 2202, loss = 3.47042753
# Iteration 2203, loss = 3.47018120
# Iteration 2204, loss = 3.46991693
# Iteration 2205, loss = 3.46972192
# Iteration 2206, loss = 3.46944149
# Iteration 2207, loss = 3.46907372
# Iteration 2208, loss = 3.46920816
# Iteration 2209, loss = 3.46863480
# Iteration 2210, loss = 3.46849784
# Iteration 2211, loss = 3.46822242
# Iteration 2212, loss = 3.46793140
# Iteration 2213, loss = 3.46770350
# Iteration 2214, loss = 3.46759191
# Iteration 2215, loss = 3.46735073
# Iteration 2216, loss = 3.46727984
# Iteration 2217, loss = 3.46694038
# Iteration 2218, loss = 3.46668305
# Iteration 2219, loss = 3.46655443
# Iteration 2220, loss = 3.46629560
# Iteration 2221, loss = 3.46608398
# Iteration 2222, loss = 3.46583671
# Iteration 2223, loss = 3.46554068
# Iteration 2224, loss = 3.46524364
# Iteration 2225, loss = 3.46504270
# Iteration 2226, loss = 3.46482454
# Iteration 2227, loss = 3.46462800
# Iteration 2228, loss = 3.46445912
# Iteration 2229, loss = 3.46434139
# Iteration 2230, loss = 3.46395812
# Iteration 2231, loss = 3.46379769
# Iteration 2232, loss = 3.46362181
# Iteration 2233, loss = 3.46329234
# Iteration 2234, loss = 3.46301960
# Iteration 2235, loss = 3.46285738
# Iteration 2236, loss = 3.46273454
# Iteration 2237, loss = 3.46240289
# Iteration 2238, loss = 3.46231103
# Iteration 2239, loss = 3.46215600
# Iteration 2240, loss = 3.46198705
# Iteration 2241, loss = 3.46178997
# Iteration 2242, loss = 3.46150423
# Iteration 2243, loss = 3.46118597
# Iteration 2244, loss = 3.46094757
# Iteration 2245, loss = 3.46074186
# Iteration 2246, loss = 3.46037545
# Iteration 2247, loss = 3.46019840
# Iteration 2248, loss = 3.45999915
# Iteration 2249, loss = 3.45982945
# Iteration 2250, loss = 3.45971193
# Iteration 2251, loss = 3.45958414
# Iteration 2252, loss = 3.45923761
# Iteration 2253, loss = 3.45891593
# Iteration 2254, loss = 3.45872547
# Iteration 2255, loss = 3.45850638
# Iteration 2256, loss = 3.45831431
# Iteration 2257, loss = 3.45804320
# Iteration 2258, loss = 3.45777782
# Iteration 2259, loss = 3.45754891
# Iteration 2260, loss = 3.45734872
# Iteration 2261, loss = 3.45718734
# Iteration 2262, loss = 3.45706500
# Iteration 2263, loss = 3.45693433
# Iteration 2264, loss = 3.45701550
# Iteration 2265, loss = 3.45662846
# Iteration 2266, loss = 3.45616043
# Iteration 2267, loss = 3.45614345
# Iteration 2268, loss = 3.45600585
# Iteration 2269, loss = 3.45554815
# Iteration 2270, loss = 3.45529792
# Iteration 2271, loss = 3.45519204
# Iteration 2272, loss = 3.45506555
# Iteration 2273, loss = 3.45462548
# Iteration 2274, loss = 3.45437773
# Iteration 2275, loss = 3.45458856
# Iteration 2276, loss = 3.45391337
# Iteration 2277, loss = 3.45398883
# Iteration 2278, loss = 3.45374034
# Iteration 2279, loss = 3.45345702
# Iteration 2280, loss = 3.45330428
# Iteration 2281, loss = 3.45304867
# Iteration 2282, loss = 3.45277982
# Iteration 2283, loss = 3.45259598
# Iteration 2284, loss = 3.45241900
# Iteration 2285, loss = 3.45218635
# Iteration 2286, loss = 3.45189702
# Iteration 2287, loss = 3.45159118
# Iteration 2288, loss = 3.45140185
# Iteration 2289, loss = 3.45121982
# Iteration 2290, loss = 3.45104543
# Iteration 2291, loss = 3.45084280
# Iteration 2292, loss = 3.45061209
# Iteration 2293, loss = 3.45042869
# Iteration 2294, loss = 3.45010184
# Iteration 2295, loss = 3.44987908
# Iteration 2296, loss = 3.44961408
# Iteration 2297, loss = 3.44940819
# Iteration 2298, loss = 3.44917972
# Iteration 2299, loss = 3.44926603
# Iteration 2300, loss = 3.44909306
# Iteration 2301, loss = 3.44940051
# Iteration 2302, loss = 3.44895875
# Iteration 2303, loss = 3.44850621
# Iteration 2304, loss = 3.44844783
# Iteration 2305, loss = 3.44832848
# Iteration 2306, loss = 3.44788670
# Iteration 2307, loss = 3.44766328
# Iteration 2308, loss = 3.44746294
# Iteration 2309, loss = 3.44725663
# Iteration 2310, loss = 3.44699554
# Iteration 2311, loss = 3.44671760
# Iteration 2312, loss = 3.44650666
# Iteration 2313, loss = 3.44626816
# Iteration 2314, loss = 3.44615866
# Iteration 2315, loss = 3.44593685
# Iteration 2316, loss = 3.44567413
# Iteration 2317, loss = 3.44543884
# Iteration 2318, loss = 3.44520927
# Iteration 2319, loss = 3.44503334
# Iteration 2320, loss = 3.44485568
# Iteration 2321, loss = 3.44464316
# Iteration 2322, loss = 3.44449971
# Iteration 2323, loss = 3.44446323
# Iteration 2324, loss = 3.44427674
# Iteration 2325, loss = 3.44384939
# Iteration 2326, loss = 3.44381472
# Iteration 2327, loss = 3.44375542
# Iteration 2328, loss = 3.44337405
# Iteration 2329, loss = 3.44316726
# Iteration 2330, loss = 3.44311796
# Iteration 2331, loss = 3.44297006
# Iteration 2332, loss = 3.44268073
# Iteration 2333, loss = 3.44243185
# Iteration 2334, loss = 3.44219850
# Iteration 2335, loss = 3.44208542
# Iteration 2336, loss = 3.44181126
# Iteration 2337, loss = 3.44159918
# Iteration 2338, loss = 3.44147829
# Iteration 2339, loss = 3.44118728
# Iteration 2340, loss = 3.44100478
# Iteration 2341, loss = 3.44125479
# Iteration 2342, loss = 3.44101044
# Iteration 2343, loss = 3.44143643
# Iteration 2344, loss = 3.44090519
# Iteration 2345, loss = 3.44021983
# Iteration 2346, loss = 3.44041341
# Iteration 2347, loss = 3.44050950
# Iteration 2348, loss = 3.43998999
# Iteration 2349, loss = 3.43958633
# Iteration 2350, loss = 3.43961249
# Iteration 2351, loss = 3.43951722
# Iteration 2352, loss = 3.43917052
# Iteration 2353, loss = 3.43880651
# Iteration 2354, loss = 3.43863284
# Iteration 2355, loss = 3.43895765
# Iteration 2356, loss = 3.43833307
# Iteration 2357, loss = 3.43890888
# Iteration 2358, loss = 3.43859138
# Iteration 2359, loss = 3.43781869
# Iteration 2360, loss = 3.43779358
# Iteration 2361, loss = 3.43791146
# Iteration 2362, loss = 3.43755353
# Iteration 2363, loss = 3.43700079
# Iteration 2364, loss = 3.43693310
# Iteration 2365, loss = 3.43688045
# Iteration 2366, loss = 3.43664665
# Iteration 2367, loss = 3.43630508
# Iteration 2368, loss = 3.43606746
# Iteration 2369, loss = 3.43591940
# Iteration 2370, loss = 3.43593235
# Iteration 2371, loss = 3.43559174
# Iteration 2372, loss = 3.43631511
# Iteration 2373, loss = 3.43595988
# Iteration 2374, loss = 3.43519779
# Iteration 2375, loss = 3.43521774
# Iteration 2376, loss = 3.43542174
# Iteration 2377, loss = 3.43499723
# Iteration 2378, loss = 3.43423928
# Iteration 2379, loss = 3.43420973
# Iteration 2380, loss = 3.43435711
# Iteration 2381, loss = 3.43412205
# Iteration 2382, loss = 3.43365980
# Iteration 2383, loss = 3.43340289
# Iteration 2384, loss = 3.43376013
# Iteration 2385, loss = 3.43323930
# Iteration 2386, loss = 3.43216235
# Iteration 2387, loss = 3.43134130
# Iteration 2388, loss = 3.43119188
# Iteration 2389, loss = 3.43113367
# Iteration 2390, loss = 3.43085870
# Iteration 2391, loss = 3.43015496
# Iteration 2392, loss = 3.42909658
# Iteration 2393, loss = 3.43137799
# Iteration 2394, loss = 3.42955464
# Iteration 2395, loss = 3.43604071
# Iteration 2396, loss = 3.43547491
# Iteration 2397, loss = 3.43285505
# Iteration 2398, loss = 3.43149800
# Iteration 2399, loss = 3.43281024
# Iteration 2400, loss = 3.43243244
# Iteration 2401, loss = 3.43162343
# Iteration 2402, loss = 3.43106159
# Iteration 2403, loss = 3.43106133
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(3, 3, 3, 3, 3), max_iter=10000, verbose=True)

# %%
print(f"Accuracy: {model.score(X_test, Y_test)}")
Y_pred = model.predict(X_test)
# Out:
# Accuracy: 0.3181818181818182

# %% [markdown]
# Well that doesn't look too good! After fitting the Neural Network, we are greeted with a very low accuracy score. Let's explore what might have gone wrong here.
#
# ### How Accuracy is Calculated in SKLearn<a name="acc"></a>
#
# `MLPClassifier`'s `score` method returns the **accuracy** metric between the predictions and the true labels. **Accuracy** is the measure of how many items the Neural Network gets correct out of all of the predictions. Think of it as you are taking a multiple choice test -- if you get it right, you get the mark, however if you get it wrong, there are no partial marks given.
#
# This works great for **multi-class** problems, because multi-class classification problems are quite literally multiple choice problems!
#
# <img src="images/labpred.png" alt="Cannot display image" width=900px>
#
# However, when dealing with multi-task classification, we are trying to predict on several classes independently. In this case, Accuracy metric works very poorly. Heres a figure explaining why:
#
# <img src="images/predlab1.png" alt="Cannot display image" width=900px>
#
# Suppose this is from a multi-task classifier used to detect ingredients in candies. Notice how for 8 classes the classifier predicted the output correctly. However, because of one mistake, the entire example is marked wrong. This is why in multi-task classification, we actually need to find the accuracies of the individual classes.

# %%
def multi_task_acc(Y_true, Y_pred):
    """ Calculates the Accuracy for each class
    Args:
        Y_true: np.ndarray containing class labels. shape = (num_examples x num_classes)
        Y_pred: np.ndarray containing predicted outputs. shape same as Y_true
        
    Returns:
        df: pd.DataFrame with the columns being the string name of each class, 
            and the index containing the accuracy
    """
    
    # diff will contain 0 if elements are the same, 1 if different
    diff = np.absolute(Y_true - Y_pred)

    # calculates how many errors are in each class
    sum_down = np.sum(diff, axis=0).astype(float)
    num_of_items = float(Y_true.shape[0])
    
    # Calculates accuracies
    accuracies = (1-(sum_down/num_of_items)).reshape(1, -1)
    df = pd.DataFrame(accuracies, columns=dataset.columns[1:10], index=["accuracy"])
    return df
    
multi_task_acc(Y_test, Y_pred)
# Out:
#           chocolate    fruity   caramel  peanutyalmondy  nougat  \
# accuracy   0.863636  0.772727  0.818182        0.818182     1.0
#
#           crispedricewafer      hard       bar  pluribus
# accuracy          0.954545  0.863636  0.772727  0.681818

# %% [markdown]
# By calculating the accuracies of each individual class, we are able to obtain more reasonable results. Next up, lets also calculate the F1 scores of each class
#
# ### Other Metrics <a name="other"></a>
#
# For a recap, the reason why we use F1 score is because **accuracy only tells us how many predictions we got right, however it does not account for imbalanced classes**, whereas **precision** and **recall** excels with datasets with large number of negative labels. F1 score is a combination of precision and recall, and thus this metric is often used **alongside** accuracy to give us a better sense of how well the Neural Network is actually doing.

# %%
from sklearn.metrics import f1_score

def multi_task_f1(Y_true, Y_pred):
    fscores = []
    for i in range(Y_true.shape[1]):
        yt = Y_true[:, i].flatten()
        yp = Y_pred[:, i].flatten()
        fscores.append(f1_score(yt, yp))
    fscores = np.array(fscores).reshape(1, -1)
    df = pd.DataFrame(fscores, columns=dataset.columns[1:10], index=["f1"])
    return df
    
    
multi_task_f1(Y_test, Y_pred)
# Out:
# /home/zonyyu/Documents/Programming Projects/Project Files/M2MTech/Beginner AI Course/workshop-4-neural-networks/env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1495: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(
#     chocolate    fruity  caramel  peanutyalmondy  nougat  crispedricewafer  \
# f1   0.857143  0.761905      0.0             0.0     0.0               0.0
#
#     hard       bar  pluribus
# f1   0.0  0.615385      0.72

# %% [markdown]
# When we display the F1 scores for each class, we notice many classes have an **F1 score of 0**. So far, we have seen the accuracy metric as well as the F1 score metric, and currently it's still not giving us a clue on how well the Neural Network really is doing. Maybe visualizing the confusion matrices might give us some clues.
#
# To plot the confusion matrices, we will use `SeaBorn`'s `heatmap` method. Because this is a multi-task classification task, we are going to **plot individual confusion matrices for each task**.

# %%
from sklearn.metrics import multilabel_confusion_matrix

classlst = list(dataset.columns.values[1:10])
print(classlst)
conf_mats = multilabel_confusion_matrix(Y_test, Y_pred)

fig, axes = plt.subplots(conf_mats.shape[0], 1, figsize=(5, 45))

for i in range(conf_mats.shape[0]):
    sn.heatmap(conf_mats[i],ax=axes[i], annot=True, cmap=sn.color_palette("Blues",12))
    axes[i].set_title(classlst[i])
# Out:
# ['chocolate', 'fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus']

# %% [markdown]
# ### Conclusions <a name="conclusions"></a>
#
# Overall, after examining the confusion matrices as well as our accuracy and F1 matrics, we can conclude that this neural network performs rather poorly in some tasks, whereas in other tasks, notably on predicting the existance of **chocolate**, the Neural Network performs quite good. In the end, you chose to deploy your Neural Network for **Skootles**. The product developemnt team used the values of **90%** popularity and **10%** relative cost as inputs to the network:

# %%
X_in = scaler.transform(poly.transform(np.array([[0.1, 90]])))

Y_out = model.predict(X_in).reshape(1, -1)

prediction_df = pd.DataFrame(Y_out, columns=dataset.columns[1:10], index=["Prediction"])
prediction_df
# Out:
#             chocolate  fruity  caramel  peanutyalmondy  nougat  \
# Prediction          1       0        0               0       0
#
#             crispedricewafer  hard  bar  pluribus
# Prediction                 0     0    1         0

# %% [markdown]
# #### Question for Students:
#
# What might be the reason for the poor performance of this Neural Network?
# ___

# %% [markdown]
# ## $\mathcal{Fin}$ <a name="fin"></a>
#
# Congrats on reaching the end of this notebook! Hope you have understood the inner workings of Neural Networks, as well as their applications. Up next, we are going to explore Neural Networks using the powerful tools provided in PyTorch. Stay Tuned....
#
# <img src="images/meme.jpeg" alt="cannot display image" width="700px">
